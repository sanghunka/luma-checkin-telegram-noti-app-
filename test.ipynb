# %%
import os
import requests
import json
from datetime import datetime, timedelta
from dotenv import load_dotenv

# .env 로드
load_dotenv()

# API 설정
api_key = os.getenv('LUMA_API_KEY')
url = "https://api.lu.ma/public/v1/calendar/list-events"
headers = {
    "Authorization": f"Bearer {api_key}",
    "Content-Type": "application/json"
}

def get_event_guests(event_id):
    """특정 이벤트의 참석자 목록 조회"""
    guests_url = "https://api.lu.ma/public/v1/event/get-guests"
    params = {
        "event_api_id": event_id,
        "approval_status": "approved"
    }
    
    try:
        response = requests.get(guests_url, headers=headers, params=params)
        if response.status_code == 200:
            data = response.json()
            return data.get('entries', [])
        else:
            print(f"      ❌ 참석자 조회 실패: {response.status_code}")
            return []
    except Exception as e:
        print(f"      💥 참석자 조회 오류: {e}")
        return []


print("🔍 Luma API 테스트 중...")
print(f"URL: {url}")
print(f"API Key: {api_key[:10]}...")

# 현재 시각 기준 앞뒤 7일 계산
now = datetime.utcnow()
after_date = now - timedelta(days=7)
before_date = now + timedelta(days=7)

# date_str = "2025-06-10T09:00:00.000Z"
# event_datetime = datetime.fromisoformat(date_str.replace('Z', '+00:00'))

# after_date = event_datetime


# ISO 8601 형식으로 변환
before_iso = before_date.strftime('%Y-%m-%dT%H:%M:%S.%fZ')[:-3] + 'Z'
after_iso = after_date.strftime('%Y-%m-%dT%H:%M:%S.%fZ')[:-3] + 'Z'

# print(after_iso)

# 쿼리 파라미터 설정
params = {
    "before": before_iso,
    "after": after_iso
}

print(f"조회 기간: {after_iso} ~{before_iso}")
print(f"조회 범위: 7일 전 ~ 7일 후 이벤트")

# API 호출
try:
    response = requests.get(url, headers=headers, params=params)
    print(f"상태 코드: {response.status_code}")
    
    if response.status_code == 200:
        data = response.json()
        events = data.get('entries', [])
        print(f"✅ 성공! {len(events)}개 이벤트 발견")
        
    else:
        print(f"❌ 실패: {response.text}")
        
except Exception as e:
    print(f"💥 오류: {e}")


if events:
        print(f"\n=== 전체 이벤트 목록 ===")
        for i, entry in enumerate(events, 1):
            event = entry.get('event', {})
            event_id = event.get('api_id')
            event_name = event.get('name')
            
            print(f"{i}. 이름: {event_name}")
            print(f"   ID: {event_id}")
            print(f"   시작: {event.get('start_at')}")
            print(f"   종료: {event.get('end_at')}")

print("\n테스트 완료!")
# Out:
# 🔍 Luma API 테스트 중...
# URL: https://api.lu.ma/public/v1/calendar/list-events
# API Key: secret-cHP...
# 2025-06-10T09:00:00.0000Z
# /var/folders/qj/2p60t76j7ws5_wjdvjddfdqw0000gn/T/ipykernel_46769/2290803882.py:44: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   now = datetime.utcnow()
# 상태 코드: 200
# ✅ 성공! 6개 이벤트 발견
#
# === 전체 이벤트 목록 ===
# 1. 이름: Spacecoin VIP Night Tokyo
#    ID: evt-tP03iqkZlwNKzBh
#    시작: 2025-06-11T09:00:00.000Z
#    종료: 2025-06-11T12:00:00.000Z
# 2. 이름: Test by SanghunKang
#    ID: evt-RnsFFJW6vE8tFnQ
#    시작: 2025-06-12T08:30:00.000Z
#    종료: 2025-06-13T09:30:00.000Z
# 3. 이름: Spacecoin VIP Night Lagos
#    ID: evt-mfCP8RoCrQgOOlL
#    시작: 2025-06-24T17:00:00.000Z
#    종료: 2025-06-24T20:30:00.000Z
# 4. 이름: Cafe GM by Spacecoin & GSR - DePIN & RWA & Web3 | Day1
#    ID: evt-bWGGkO5q74oRkQQ
#    시작: 2025-07-01T09:00:00.000Z
#    종료: 2025-07-01T18:00:00.000Z
# 5. 이름: Cafe GM by Spacecoin & GSR - DePIN & RWA & Web3 | Day2
#    ID: evt-YtviZDBwjcOBtZY
#    시작: 2025-07-02T09:00:00.000Z
#    종료: 2025-07-02T18:00:00.000Z
# 6. 이름: Cafe GM by Spacecoin & GSR - DePIN & RWA & Web3
#    ID: evt-oqjhzT4KVdupKDY
#    시작: 2025-07-04T02:00:00.000Z
#    종료: 2025-07-04T12:00:00.000Z
#
# 테스트 완료!

# %%
events[0]['api_id']
# Out:
# 'evt-tP03iqkZlwNKzBh'

# %%
def get_event_guests(event_id):
    """특정 이벤트의 참석자 목록 조회"""
    guests_url = "https://api.lu.ma/public/v1/event/get-guests"
    params = {
        "event_api_id": event_id,
        "approval_status": "approved"
    }
    
    try:
        response = requests.get(guests_url, headers=headers, params=params)
        if response.status_code == 200:
            data = response.json()
            return data.get('entries', [])
        else:
            print(f"      ❌ 참석자 조회 실패: {response.status_code}")
            return []
    except Exception as e:
        print(f"      💥 참석자 조회 오류: {e}")
        return []
# Out:
# [{'api_id': 'gst-2xnNgcCT83aKPzj',
#   'guest': {'api_id': 'gst-2xnNgcCT83aKPzj',
#    'approval_status': 'approved',
#    'created_at': '2025-05-30T16:01:55.294Z',
#    'custom_source': None,
#    'eth_address': None,
#    'invited_at': None,
#    'joined_at': None,
#    'phone_number': None,
#    'registered_at': '2025-05-30T16:01:55.293Z',
#    'registration_answers': [{'label': 'Name or Alias',
#      'answer': 'Amechan',
#      'question_id': 'pg6lhrro',
#      'question_type': 'text'},
#     {'label': 'Area of activity in Web3',
#      'answer': 'Marketing',
#      'question_id': 'jlm8db1x',
#      'question_type': 'text'},
#     {'label': 'Telegram handle',
#      'answer': 'web3ame',
#      'question_id': 'vd7qlwtn',
#      'question_type': 'text'},
#     {'label': 'X (Twitter) handle',
#      'answer': 'https://x.com/kawaiigirlnft',
#      'question_id': 'j7ohhsuw',
#      'question_type': 'text'},
#     {'label': 'Who invited you?',
#      'answer': 'BZB',
#      'question_id': 'hs5j82g7',
#      'question_type': 'text'}],
#    'solana_address': None,
#    'user_api_id': 'usr-VPvpKzwiGIA27oZ',
#    'user_name': 'Ame-chan',
#    'user_email': 'amechan@buzzbridge.capital',
#    'user_first_name': 'Ame',
#    'user_last_name': 'Chan',
#    'name': 'Ame-chan',
#    'email': 'amechan@buzzbridge.capital',
#    'checked_in_at': None,
#    'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-0tUvj7EDvDyl7hJ',
#    'event_tickets': [{'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-ncYM6hlyiO1sF49',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}],
#    'event_ticket': {'amount': 0,
#     'amount_discount': 0,
#     'amount_tax': 0,
#     'api_id': 'eventticket-ncYM6hlyiO1sF49',
#     'checked_in_at': None,
#     'currency': 'usd',
#     'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#     'is_captured': False,
#     'name': 'VIP'}}},
#  {'api_id': 'gst-n7dvxo5DnG8VuRg',
#   'guest': {'api_id': 'gst-n7dvxo5DnG8VuRg',
#    'approval_status': 'approved',
#    'created_at': '2025-06-03T16:30:17.647Z',
#    'custom_source': None,
#    'eth_address': None,
#    'invited_at': None,
#    'joined_at': None,
#    'phone_number': None,
#    'registered_at': '2025-06-03T16:30:17.646Z',
#    'registration_answers': [{'label': 'Name or Alias',
#      'answer': 'taka.eth',
#      'question_id': 'pg6lhrro',
#      'question_type': 'text'},
#     {'label': 'Area of activity in Web3',
#      'answer': 'Community builder',
#      'question_id': 'jlm8db1x',
#      'question_type': 'text'},
#     {'label': 'Telegram handle',
#      'answer': 'taka_eth',
#      'question_id': 'vd7qlwtn',
#      'question_type': 'text'},
#     {'label': 'X (Twitter) handle',
#      'answer': 'https://x.com/taka_eth',
#      'question_id': 'j7ohhsuw',
#      'question_type': 'text'},
#     {'label': 'Who invited you?',
#      'answer': 'BZB',
#      'question_id': 'hs5j82g7',
#      'question_type': 'text'}],
#    'solana_address': None,
#    'user_api_id': 'usr-H1TErLDY4NCGLgr',
#    'user_name': 'taka.eth',
#    'user_email': 'taka@boardingbridge.org',
#    'user_first_name': ' ',
#    'user_last_name': 'taka.eth',
#    'name': 'taka.eth',
#    'email': 'taka@boardingbridge.org',
#    'checked_in_at': None,
#    'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-ROKVAcVEBlTLfOO',
#    'event_tickets': [{'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-tYwnooQy4a4gr1g',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}],
#    'event_ticket': {'amount': 0,
#     'amount_discount': 0,
#     'amount_tax': 0,
#     'api_id': 'eventticket-tYwnooQy4a4gr1g',
#     'checked_in_at': None,
#     'currency': 'usd',
#     'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#     'is_captured': False,
#     'name': 'VIP'}}},
#  {'api_id': 'gst-6dU1rcEGEg5yxWQ',
#   'guest': {'api_id': 'gst-6dU1rcEGEg5yxWQ',
#    'approval_status': 'approved',
#    'created_at': '2025-06-03T16:31:51.146Z',
#    'custom_source': None,
#    'eth_address': None,
#    'invited_at': None,
#    'joined_at': None,
#    'phone_number': None,
#    'registered_at': '2025-06-03T16:31:51.145Z',
#    'registration_answers': [{'label': 'Name or Alias',
#      'answer': 'Yokota Shogo',
#      'question_id': 'pg6lhrro',
#      'question_type': 'text'},
#     {'label': 'Area of activity in Web3',
#      'answer': 'NFT GAME',
#      'question_id': 'jlm8db1x',
#      'question_type': 'text'},
#     {'label': 'Telegram handle',
#      'answer': 'goshou1031',
#      'question_id': 'vd7qlwtn',
#      'question_type': 'text'},
#     {'label': 'X (Twitter) handle',
#      'answer': 'https://x.com/gosho1031',
#      'question_id': 'j7ohhsuw',
#      'question_type': 'text'},
#     {'label': 'Who invited you?',
#      'answer': 'WEB3HONEY',
#      'question_id': 'hs5j82g7',
#      'question_type': 'text'}],
#    'solana_address': None,
#    'user_api_id': 'usr-u1raz4KVRVGUzAd',
#    'user_name': '横田昇吾',
#    'user_email': 's.yokota@blockchaingame.co.jp',
#    'user_first_name': '昇吾',
#    'user_last_name': '横田',
#    'name': '横田昇吾',
#    'email': 's.yokota@blockchaingame.co.jp',
#    'checked_in_at': None,
#    'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-U9oK5Pm4paOHaXK',
#    'event_tickets': [{'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-yLUhg3J1WXZkBNx',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}],
#    'event_ticket': {'amount': 0,
#     'amount_discount': 0,
#     'amount_tax': 0,
#     'api_id': 'eventticket-yLUhg3J1WXZkBNx',
#     'checked_in_at': None,
#     'currency': 'usd',
#     'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#     'is_captured': False,
#     'name': 'VIP'}}},
#  {'api_id': 'gst-lKAPeXk0Or4USZz',
#   'guest': {'api_id': 'gst-lKAPeXk0Or4USZz',
#    'approval_status': 'approved',
#    'created_at': '2025-06-03T16:42:09.788Z',
#    'custom_source': None,
#    'eth_address': None,
#    'invited_at': None,
#    'joined_at': None,
#    'phone_number': None,
#    'registered_at': '2025-06-03T16:42:09.787Z',
#    'registration_answers': [{'label': 'Name or Alias',
#      'answer': 'NOROI GAMIES',
#      'question_id': 'pg6lhrro',
#      'question_type': 'text'},
#     {'label': 'Area of activity in Web3',
#      'answer': 'Web3 Gaming',
#      'question_id': 'jlm8db1x',
#      'question_type': 'text'},
#     {'label': 'Telegram handle',
#      'answer': 'noroichan_game',
#      'question_id': 'vd7qlwtn',
#      'question_type': 'text'},
#     {'label': 'X (Twitter) handle',
#      'answer': 'https://x.com/noroichan_game',
#      'question_id': 'j7ohhsuw',
#      'question_type': 'text'},
#     {'label': 'Who invited you?',
#      'answer': 'BZB',
#      'question_id': 'hs5j82g7',
#      'question_type': 'text'}],
#    'solana_address': None,
#    'user_api_id': 'usr-wMAwE3xnBXRyDuZ',
#    'user_name': 'NOROI',
#    'user_email': 'noroichan.m@gmail.com',
#    'user_first_name': 'ちゃん',
#    'user_last_name': 'のろい',
#    'name': 'NOROI',
#    'email': 'noroichan.m@gmail.com',
#    'checked_in_at': None,
#    'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-g2ndJ8ljhXUpHJe',
#    'event_tickets': [{'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-GaqNlk5Hy18bPKA',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}],
#    'event_ticket': {'amount': 0,
#     'amount_discount': 0,
#     'amount_tax': 0,
#     'api_id': 'eventticket-GaqNlk5Hy18bPKA',
#     'checked_in_at': None,
#     'currency': 'usd',
#     'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#     'is_captured': False,
#     'name': 'VIP'}}},
#  {'api_id': 'gst-Ae1sHVWeK47YuBC',
#   'guest': {'api_id': 'gst-Ae1sHVWeK47YuBC',
#    'approval_status': 'approved',
#    'created_at': '2025-06-03T16:49:40.823Z',
#    'custom_source': None,
#    'eth_address': None,
#    'invited_at': None,
#    'joined_at': None,
#    'phone_number': None,
#    'registered_at': '2025-06-03T16:49:40.823Z',
#    'registration_answers': [{'label': 'Name or Alias',
#      'answer': 'Makoto Aoki',
#      'question_id': 'pg6lhrro',
#      'question_type': 'text'},
#     {'label': 'Area of activity in Web3',
#      'answer': 'Media',
#      'question_id': 'jlm8db1x',
#      'question_type': 'text'},
#     {'label': 'Telegram handle',
#      'answer': 'Makoto_CoinPost',
#      'question_id': 'vd7qlwtn',
#      'question_type': 'text'},
#     {'label': 'X (Twitter) handle',
#      'answer': 'https://x.com/Makoto_CoinPost',
#      'question_id': 'j7ohhsuw',
#      'question_type': 'text'},
#     {'label': 'Who invited you?',
#      'answer': 'BZB',
#      'question_id': 'hs5j82g7',
#      'question_type': 'text'}],
#    'solana_address': None,
#    'user_api_id': 'usr-47JhC2ApRSL5GCa',
#    'user_name': 'Makoto Aoki',
#    'user_email': 'a.makoto@coinpost.jp',
#    'user_first_name': 'Makoto',
#    'user_last_name': 'Aoki',
#    'name': 'Makoto Aoki',
#    'email': 'a.makoto@coinpost.jp',
#    'checked_in_at': None,
#    'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-eCEQpETNcblEWX7',
#    'event_tickets': [{'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-ve8GrUaBEVcthPm',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}],
#    'event_ticket': {'amount': 0,
#     'amount_discount': 0,
#     'amount_tax': 0,
#     'api_id': 'eventticket-ve8GrUaBEVcthPm',
#     'checked_in_at': None,
#     'currency': 'usd',
#     'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#     'is_captured': False,
#     'name': 'VIP'}}},
#  {'api_id': 'gst-108JcQnXyfbU408',
#   'guest': {'api_id': 'gst-108JcQnXyfbU408',
#    'approval_status': 'approved',
#    'created_at': '2025-06-03T17:02:36.717Z',
#    'custom_source': None,
#    'eth_address': None,
#    'invited_at': None,
#    'joined_at': None,
#    'phone_number': None,
#    'registered_at': '2025-06-03T17:02:36.715Z',
#    'registration_answers': [{'label': 'Name or Alias',
#      'answer': 'Luin Aozora',
#      'question_id': 'pg6lhrro',
#      'question_type': 'text'},
#     {'label': 'Area of activity in Web3',
#      'answer': 'Web3 Game',
#      'question_id': 'jlm8db1x',
#      'question_type': 'text'},
#     {'label': 'Telegram handle',
#      'answer': 'luin_aozora',
#      'question_id': 'vd7qlwtn',
#      'question_type': 'text'},
#     {'label': 'X (Twitter) handle',
#      'answer': '@luin_aozora',
#      'question_id': 'j7ohhsuw',
#      'question_type': 'text'},
#     {'label': 'Who invited you?',
#      'answer': 'BZB',
#      'question_id': 'hs5j82g7',
#      'question_type': 'text'}],
#    'solana_address': None,
#    'user_api_id': 'usr-3VVwVtLkjgLPMcG',
#    'user_name': 'Luin Aozora',
#    'user_email': 'luin.aozora@gmail.com',
#    'user_first_name': 'Luin',
#    'user_last_name': 'Aozora',
#    'name': 'Luin Aozora',
#    'email': 'luin.aozora@gmail.com',
#    'checked_in_at': None,
#    'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-Tv3Vsz2dUQQC2Eb',
#    'event_tickets': [{'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-yX9MEb6YTPW78Wj',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}],
#    'event_ticket': {'amount': 0,
#     'amount_discount': 0,
#     'amount_tax': 0,
#     'api_id': 'eventticket-yX9MEb6YTPW78Wj',
#     'checked_in_at': None,
#     'currency': 'usd',
#     'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#     'is_captured': False,
#     'name': 'VIP'}}},
#  {'api_id': 'gst-AGAUmv3Gu46sXSx',
#   'guest': {'api_id': 'gst-AGAUmv3Gu46sXSx',
#    'approval_status': 'approved',
#    'created_at': '2025-06-03T17:05:11.549Z',
#    'custom_source': None,
#    'eth_address': None,
#    'invited_at': None,
#    'joined_at': None,
#    'phone_number': None,
#    'registered_at': '2025-06-03T17:05:11.549Z',
#    'registration_answers': [{'label': 'Name or Alias',
#      'answer': 'Aku',
#      'question_id': 'pg6lhrro',
#      'question_type': 'text'},
#     {'label': 'Area of activity in Web3',
#      'answer': 'KOL',
#      'question_id': 'jlm8db1x',
#      'question_type': 'text'},
#     {'label': 'Telegram handle',
#      'answer': '@aku00aku',
#      'question_id': 'vd7qlwtn',
#      'question_type': 'text'},
#     {'label': 'X (Twitter) handle',
#      'answer': '@A4lLfa7',
#      'question_id': 'j7ohhsuw',
#      'question_type': 'text'},
#     {'label': 'Who invited you?',
#      'answer': 'BZB',
#      'question_id': 'hs5j82g7',
#      'question_type': 'text'}],
#    'solana_address': None,
#    'user_api_id': 'usr-B0Zz1UXBcpuJybU',
#    'user_name': 'Aku',
#    'user_email': 'amoonlight8558@gmail.com',
#    'user_first_name': 'Aku',
#    'user_last_name': '',
#    'name': 'Aku',
#    'email': 'amoonlight8558@gmail.com',
#    'checked_in_at': None,
#    'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-DiNKOywbLbTgkTv',
#    'event_tickets': [{'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-uzgKRNvsnvnrLOg',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}],
#    'event_ticket': {'amount': 0,
#     'amount_discount': 0,
#     'amount_tax': 0,
#     'api_id': 'eventticket-uzgKRNvsnvnrLOg',
#     'checked_in_at': None,
#     'currency': 'usd',
#     'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#     'is_captured': False,
#     'name': 'VIP'}}},
#  {'api_id': 'gst-RDMFWOqY3uO1Ok1',
#   'guest': {'api_id': 'gst-RDMFWOqY3uO1Ok1',
#    'approval_status': 'approved',
#    'created_at': '2025-06-03T19:43:16.061Z',
#    'custom_source': None,
#    'eth_address': None,
#    'invited_at': None,
#    'joined_at': None,
#    'phone_number': None,
#    'registered_at': '2025-06-03T19:43:16.061Z',
#    'registration_answers': [{'label': 'Name or Alias',
#      'answer': 'Akira Komiya',
#      'question_id': 'pg6lhrro',
#      'question_type': 'text'},
#     {'label': 'Area of activity in Web3',
#      'answer': 'Japan',
#      'question_id': 'jlm8db1x',
#      'question_type': 'text'},
#     {'label': 'Telegram handle',
#      'answer': 'akirakomiyas',
#      'question_id': 'vd7qlwtn',
#      'question_type': 'text'},
#     {'label': 'X (Twitter) handle',
#      'answer': 'komiya5395',
#      'question_id': 'j7ohhsuw',
#      'question_type': 'text'},
#     {'label': 'Who invited you?',
#      'answer': 'BZB',
#      'question_id': 'hs5j82g7',
#      'question_type': 'text'}],
#    'solana_address': None,
#    'user_api_id': 'usr-01GBNOJcTGhJ0JU',
#    'user_name': 'NinjaGuild_Japan (NGG)',
#    'user_email': 'akira.komiya@guild.support',
#    'user_first_name': None,
#    'user_last_name': None,
#    'name': 'NinjaGuild_Japan (NGG)',
#    'email': 'akira.komiya@guild.support',
#    'checked_in_at': None,
#    'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-Gprf3Sf23cvXtaD',
#    'event_tickets': [{'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-C06np7lhuMVrvVF',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}],
#    'event_ticket': {'amount': 0,
#     'amount_discount': 0,
#     'amount_tax': 0,
#     'api_id': 'eventticket-C06np7lhuMVrvVF',
#     'checked_in_at': None,
#     'currency': 'usd',
#     'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#     'is_captured': False,
#     'name': 'VIP'}}},
#  {'api_id': 'gst-dYR55msypgRdXgG',
#   'guest': {'api_id': 'gst-dYR55msypgRdXgG',
#    'approval_status': 'approved',
#    'created_at': '2025-06-03T20:34:51.298Z',
#    'custom_source': None,
#    'eth_address': None,
#    'invited_at': None,
#    'joined_at': None,
#    'phone_number': None,
#    'registered_at': '2025-06-03T20:34:51.297Z',
#    'registration_answers': [{'label': 'Name or Alias',
#      'answer': 'チビクロ｜CSO - ISC',
#      'question_id': 'pg6lhrro',
#      'question_type': 'text'},
#     {'label': 'Area of activity in Web3',
#      'answer': 'KOL',
#      'question_id': 'jlm8db1x',
#      'question_type': 'text'},
#     {'label': 'Telegram handle',
#      'answer': '@Chibikuro4741',
#      'question_id': 'vd7qlwtn',
#      'question_type': 'text'},
#     {'label': 'X (Twitter) handle',
#      'answer': 'https://x.com/CHIBIKURO_QnQ',
#      'question_id': 'j7ohhsuw',
#      'question_type': 'text'},
#     {'label': 'Who invited you?',
#      'answer': 'BZB',
#      'question_id': 'hs5j82g7',
#      'question_type': 'text'}],
#    'solana_address': None,
#    'user_api_id': 'usr-7xXLkoTRAjixKk2',
#    'user_name': 'チビクロ｜CSO - ISC',
#    'user_email': 'tensyu9@gmail.com',
#    'user_first_name': '耕平',
#    'user_last_name': '山下',
#    'name': 'チビクロ｜CSO - ISC',
#    'email': 'tensyu9@gmail.com',
#    'checked_in_at': None,
#    'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-J8vi0OjG7IKWv1D',
#    'event_tickets': [{'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-oLF8VdeHGSwDNGc',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}],
#    'event_ticket': {'amount': 0,
#     'amount_discount': 0,
#     'amount_tax': 0,
#     'api_id': 'eventticket-oLF8VdeHGSwDNGc',
#     'checked_in_at': None,
#     'currency': 'usd',
#     'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#     'is_captured': False,
#     'name': 'VIP'}}},
#  {'api_id': 'gst-gQrCFkNCdw5tHXj',
#   'guest': {'api_id': 'gst-gQrCFkNCdw5tHXj',
#    'approval_status': 'approved',
#    'created_at': '2025-06-03T22:46:39.487Z',
#    'custom_source': None,
#    'eth_address': None,
#    'invited_at': None,
#    'joined_at': None,
#    'phone_number': None,
#    'registered_at': '2025-06-03T22:46:39.486Z',
#    'registration_answers': [{'label': 'Name or Alias',
#      'answer': 'gaccho',
#      'question_id': 'pg6lhrro',
#      'question_type': 'text'},
#     {'label': 'Area of activity in Web3',
#      'answer': 'X',
#      'question_id': 'jlm8db1x',
#      'question_type': 'text'},
#     {'label': 'Telegram handle',
#      'answer': '@Gaccho_0622',
#      'question_id': 'vd7qlwtn',
#      'question_type': 'text'},
#     {'label': 'X (Twitter) handle',
#      'answer': 'https://x.com/daice_0622',
#      'question_id': 'j7ohhsuw',
#      'question_type': 'text'},
#     {'label': 'Who invited you?',
#      'answer': 'たぬきちさん',
#      'question_id': 'hs5j82g7',
#      'question_type': 'text'}],
#    'solana_address': None,
#    'user_api_id': 'usr-15yUoQI9PiocL3a',
#    'user_name': 'Gaccho',
#    'user_email': 'kotiya6622@gmail.com',
#    'user_first_name': 'Gaccho',
#    'user_last_name': '',
#    'name': 'Gaccho',
#    'email': 'kotiya6622@gmail.com',
#    'checked_in_at': None,
#    'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-rKJbVUwZu3bKSPi',
#    'event_tickets': [{'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-UyExC7BoatQebee',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}],
#    'event_ticket': {'amount': 0,
#     'amount_discount': 0,
#     'amount_tax': 0,
#     'api_id': 'eventticket-UyExC7BoatQebee',
#     'checked_in_at': None,
#     'currency': 'usd',
#     'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#     'is_captured': False,
#     'name': 'VIP'}}},
#  {'api_id': 'gst-pcrZGsYemAIKIyd',
#   'guest': {'api_id': 'gst-pcrZGsYemAIKIyd',
#    'approval_status': 'approved',
#    'created_at': '2025-06-04T01:24:05.408Z',
#    'custom_source': None,
#    'eth_address': None,
#    'invited_at': None,
#    'joined_at': None,
#    'phone_number': None,
#    'registered_at': '2025-06-04T01:24:05.407Z',
#    'registration_answers': [{'label': 'Name or Alias',
#      'answer': 'AEB',
#      'question_id': 'pg6lhrro',
#      'question_type': 'text'},
#     {'label': 'Area of activity in Web3',
#      'answer': 'NFT',
#      'question_id': 'jlm8db1x',
#      'question_type': 'text'},
#     {'label': 'Telegram handle',
#      'answer': 'BUN AEB',
#      'question_id': 'vd7qlwtn',
#      'question_type': 'text'},
#     {'label': 'X (Twitter) handle',
#      'answer': 'https://x.com/aeb_nft',
#      'question_id': 'j7ohhsuw',
#      'question_type': 'text'},
#     {'label': 'Who invited you?',
#      'answer': 'BZB',
#      'question_id': 'hs5j82g7',
#      'question_type': 'text'}],
#    'solana_address': None,
#    'user_api_id': 'usr-lbOEWmpG1Xjom7T',
#    'user_name': 'A.E.B／BUN',
#    'user_email': 'aeb@whereverse.jp',
#    'user_first_name': '翔太',
#    'user_last_name': '國分',
#    'name': 'A.E.B／BUN',
#    'email': 'aeb@whereverse.jp',
#    'checked_in_at': None,
#    'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-UYLttEaFwzawze3',
#    'event_tickets': [{'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-97TAodZqSkHG3mb',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}],
#    'event_ticket': {'amount': 0,
#     'amount_discount': 0,
#     'amount_tax': 0,
#     'api_id': 'eventticket-97TAodZqSkHG3mb',
#     'checked_in_at': None,
#     'currency': 'usd',
#     'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#     'is_captured': False,
#     'name': 'VIP'}}},
#  {'api_id': 'gst-UByS7xbRVO9jAij',
#   'guest': {'api_id': 'gst-UByS7xbRVO9jAij',
#    'approval_status': 'approved',
#    'created_at': '2025-06-04T03:01:33.553Z',
#    'custom_source': None,
#    'eth_address': None,
#    'invited_at': None,
#    'joined_at': None,
#    'phone_number': None,
#    'registered_at': '2025-06-04T03:01:33.553Z',
#    'registration_answers': [{'label': 'Name or Alias',
#      'answer': 'you425',
#      'question_id': 'pg6lhrro',
#      'question_type': 'text'},
#     {'label': 'Area of activity in Web3',
#      'answer': 'Researcher',
#      'question_id': 'jlm8db1x',
#      'question_type': 'text'},
#     {'label': 'Telegram handle',
#      'answer': 'you425',
#      'question_id': 'vd7qlwtn',
#      'question_type': 'text'},
#     {'label': 'X (Twitter) handle',
#      'answer': 'https://x.com/you425you',
#      'question_id': 'j7ohhsuw',
#      'question_type': 'text'},
#     {'label': 'Who invited you?',
#      'answer': 'BZB',
#      'question_id': 'hs5j82g7',
#      'question_type': 'text'}],
#    'solana_address': None,
#    'user_api_id': 'usr-uD2qAz2jK1umrTn',
#    'user_name': 'you425',
#    'user_email': 'youdietagao@gmail.com',
#    'user_first_name': 'you',
#    'user_last_name': '425',
#    'name': 'you425',
#    'email': 'youdietagao@gmail.com',
#    'checked_in_at': None,
#    'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-DZyvQ9EoqohbNFq',
#    'event_tickets': [{'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-g2Eqc8myxUdugta',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}],
#    'event_ticket': {'amount': 0,
#     'amount_discount': 0,
#     'amount_tax': 0,
#     'api_id': 'eventticket-g2Eqc8myxUdugta',
#     'checked_in_at': None,
#     'currency': 'usd',
#     'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#     'is_captured': False,
#     'name': 'VIP'}}},
#  {'api_id': 'gst-6P9EYWHwFqvxOE7',
#   'guest': {'api_id': 'gst-6P9EYWHwFqvxOE7',
#    'approval_status': 'approved',
#    'created_at': '2025-06-04T04:44:26.897Z',
#    'custom_source': None,
#    'eth_address': None,
#    'invited_at': None,
#    'joined_at': None,
#    'phone_number': None,
#    'registered_at': '2025-06-04T04:44:26.897Z',
#    'registration_answers': [{'label': 'Name or Alias',
#      'answer': '灯篭',
#      'question_id': 'pg6lhrro',
#      'question_type': 'text'},
#     {'label': 'Area of activity in Web3',
#      'answer': 'Community / Marketing / Investment...etc',
#      'question_id': 'jlm8db1x',
#      'question_type': 'text'},
#     {'label': 'Telegram handle',
#      'answer': '@Tourou',
#      'question_id': 'vd7qlwtn',
#      'question_type': 'text'},
#     {'label': 'X (Twitter) handle',
#      'answer': '@TourouJPN',
#      'question_id': 'j7ohhsuw',
#      'question_type': 'text'},
#     {'label': 'Who invited you?',
#      'answer': 'BZB',
#      'question_id': 'hs5j82g7',
#      'question_type': 'text'}],
#    'solana_address': None,
#    'user_api_id': 'usr-Z3bXzK37E3MuLwX',
#    'user_name': 'Tourou',
#    'user_email': 'touroujpn@gmail.com',
#    'user_first_name': 'Tourou',
#    'user_last_name': '灯篭',
#    'name': 'Tourou',
#    'email': 'touroujpn@gmail.com',
#    'checked_in_at': None,
#    'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-R6IhkvNtPX9eDJT',
#    'event_tickets': [{'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-koKWVDCOULunPqt',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}],
#    'event_ticket': {'amount': 0,
#     'amount_discount': 0,
#     'amount_tax': 0,
#     'api_id': 'eventticket-koKWVDCOULunPqt',
#     'checked_in_at': None,
#     'currency': 'usd',
#     'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#     'is_captured': False,
#     'name': 'VIP'}}},
#  {'api_id': 'gst-HHwHbWkop2SCuE2',
#   'guest': {'api_id': 'gst-HHwHbWkop2SCuE2',
#    'approval_status': 'approved',
#    'created_at': '2025-06-04T05:12:58.184Z',
#    'custom_source': None,
#    'eth_address': None,
#    'invited_at': None,
#    'joined_at': None,
#    'phone_number': None,
#    'registered_at': '2025-06-04T05:12:58.183Z',
#    'registration_answers': [{'label': 'Name or Alias',
#      'answer': 'Gumi-chan',
#      'question_id': 'pg6lhrro',
#      'question_type': 'text'},
#     {'label': 'Area of activity in Web3',
#      'answer': 'NFT',
#      'question_id': 'jlm8db1x',
#      'question_type': 'text'},
#     {'label': 'Telegram handle',
#      'answer': 'miosan_gumichan',
#      'question_id': 'vd7qlwtn',
#      'question_type': 'text'},
#     {'label': 'X (Twitter) handle',
#      'answer': 'Kawaiigirl_en',
#      'question_id': 'j7ohhsuw',
#      'question_type': 'text'},
#     {'label': 'Who invited you?',
#      'answer': 'BZB',
#      'question_id': 'hs5j82g7',
#      'question_type': 'text'}],
#    'solana_address': None,
#    'user_api_id': 'usr-b0eXevuVSFUgusW',
#    'user_name': 'Mio Yonenaga',
#    'user_email': 'mio.yonenaga@sbinft.co.jp',
#    'user_first_name': 'Mio',
#    'user_last_name': 'Yonenaga',
#    'name': 'Mio Yonenaga',
#    'email': 'mio.yonenaga@sbinft.co.jp',
#    'checked_in_at': None,
#    'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-ZyEznKt7FE1BctD',
#    'event_tickets': [{'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-jWlC0HuGJEd8PHR',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}],
#    'event_ticket': {'amount': 0,
#     'amount_discount': 0,
#     'amount_tax': 0,
#     'api_id': 'eventticket-jWlC0HuGJEd8PHR',
#     'checked_in_at': None,
#     'currency': 'usd',
#     'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#     'is_captured': False,
#     'name': 'VIP'}}},
#  {'api_id': 'gst-yqwz8fPhtOsQrof',
#   'guest': {'api_id': 'gst-yqwz8fPhtOsQrof',
#    'approval_status': 'approved',
#    'created_at': '2025-06-04T05:46:01.274Z',
#    'custom_source': None,
#    'eth_address': None,
#    'invited_at': None,
#    'joined_at': None,
#    'phone_number': None,
#    'registered_at': '2025-06-04T05:46:01.273Z',
#    'registration_answers': [{'label': 'Name or Alias',
#      'answer': 'AMEYUMI',
#      'question_id': 'pg6lhrro',
#      'question_type': 'text'},
#     {'label': 'Area of activity in Web3',
#      'answer': 'NFT',
#      'question_id': 'jlm8db1x',
#      'question_type': 'text'},
#     {'label': 'Telegram handle',
#      'answer': 'xxurainbow',
#      'question_id': 'vd7qlwtn',
#      'question_type': 'text'},
#     {'label': 'X (Twitter) handle',
#      'answer': 'https://x.com/rain_vc',
#      'question_id': 'j7ohhsuw',
#      'question_type': 'text'},
#     {'label': 'Who invited you?',
#      'answer': 'BZB',
#      'question_id': 'hs5j82g7',
#      'question_type': 'text'}],
#    'solana_address': None,
#    'user_api_id': 'usr-KzxEYUED27Iwf4A',
#    'user_name': 'AMEYUMI',
#    'user_email': 'ameyumicash@gmail.com',
#    'user_first_name': '弘司',
#    'user_last_name': '北原',
#    'name': 'AMEYUMI',
#    'email': 'ameyumicash@gmail.com',
#    'checked_in_at': None,
#    'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-BgLgT8hLNhj9c0O',
#    'event_tickets': [{'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-7eKFNN10ne1T7ZH',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}],
#    'event_ticket': {'amount': 0,
#     'amount_discount': 0,
#     'amount_tax': 0,
#     'api_id': 'eventticket-7eKFNN10ne1T7ZH',
#     'checked_in_at': None,
#     'currency': 'usd',
#     'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#     'is_captured': False,
#     'name': 'VIP'}}},
#  {'api_id': 'gst-FVosfgYGoR01LM8',
#   'guest': {'api_id': 'gst-FVosfgYGoR01LM8',
#    'approval_status': 'approved',
#    'created_at': '2025-06-04T09:19:14.934Z',
#    'custom_source': None,
#    'eth_address': None,
#    'invited_at': None,
#    'joined_at': None,
#    'phone_number': None,
#    'registered_at': '2025-06-04T09:19:14.934Z',
#    'registration_answers': [{'label': 'Name or Alias',
#      'answer': 'くし/Crypto文鳥',
#      'question_id': 'pg6lhrro',
#      'question_type': 'text'},
#     {'label': 'Area of activity in Web3',
#      'answer': '仮想通貨取引所',
#      'question_id': 'jlm8db1x',
#      'question_type': 'text'},
#     {'label': 'Telegram handle',
#      'answer': '@kusi_nft',
#      'question_id': 'vd7qlwtn',
#      'question_type': 'text'},
#     {'label': 'X (Twitter) handle',
#      'answer': 'https://x.com/nft_kusi',
#      'question_id': 'j7ohhsuw',
#      'question_type': 'text'},
#     {'label': 'Who invited you?',
#      'answer': '@Ari_creditscend',
#      'question_id': 'hs5j82g7',
#      'question_type': 'text'}],
#    'solana_address': None,
#    'user_api_id': 'usr-BFBmECgIBqyxPe6',
#    'user_name': 'kusi',
#    'user_email': 'kusi18fosu@gmail.com',
#    'user_first_name': 'Kusi',
#    'user_last_name': '',
#    'name': 'kusi',
#    'email': 'kusi18fosu@gmail.com',
#    'checked_in_at': None,
#    'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-pO3voP81Yo5iQLO',
#    'event_tickets': [{'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-r5Dc3feIgsh08e9',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}],
#    'event_ticket': {'amount': 0,
#     'amount_discount': 0,
#     'amount_tax': 0,
#     'api_id': 'eventticket-r5Dc3feIgsh08e9',
#     'checked_in_at': None,
#     'currency': 'usd',
#     'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#     'is_captured': False,
#     'name': 'VIP'}}},
#  {'api_id': 'gst-QxnFbngkrSrVgsf',
#   'guest': {'api_id': 'gst-QxnFbngkrSrVgsf',
#    'approval_status': 'approved',
#    'created_at': '2025-06-04T11:21:04.477Z',
#    'custom_source': None,
#    'eth_address': None,
#    'invited_at': None,
#    'joined_at': None,
#    'phone_number': None,
#    'registered_at': '2025-06-04T11:21:04.476Z',
#    'registration_answers': [{'label': 'Name or Alias',
#      'answer': 'Tarako',
#      'question_id': 'pg6lhrro',
#      'question_type': 'text'},
#     {'label': 'Area of activity in Web3',
#      'answer': 'Token',
#      'question_id': 'jlm8db1x',
#      'question_type': 'text'},
#     {'label': 'Telegram handle',
#      'answer': '@nftarako',
#      'question_id': 'vd7qlwtn',
#      'question_type': 'text'},
#     {'label': 'X (Twitter) handle',
#      'answer': 'https://x.com/NFT_Tarako',
#      'question_id': 'j7ohhsuw',
#      'question_type': 'text'},
#     {'label': 'Who invited you?',
#      'answer': 'BZB',
#      'question_id': 'hs5j82g7',
#      'question_type': 'text'}],
#    'solana_address': None,
#    'user_api_id': 'usr-QQpAjq1U5waEDzC',
#    'user_name': '非代替性たらこ',
#    'user_email': 'nftarako@gmail.com',
#    'user_first_name': None,
#    'user_last_name': None,
#    'name': '非代替性たらこ',
#    'email': 'nftarako@gmail.com',
#    'checked_in_at': None,
#    'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-bXIFp9u2GS7H9BE',
#    'event_tickets': [{'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-Jn1J6yTklkaGlim',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}],
#    'event_ticket': {'amount': 0,
#     'amount_discount': 0,
#     'amount_tax': 0,
#     'api_id': 'eventticket-Jn1J6yTklkaGlim',
#     'checked_in_at': None,
#     'currency': 'usd',
#     'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#     'is_captured': False,
#     'name': 'VIP'}}},
#  {'api_id': 'gst-qnfFwGO6t0cCJBY',
#   'guest': {'api_id': 'gst-qnfFwGO6t0cCJBY',
#    'approval_status': 'approved',
#    'created_at': '2025-06-04T11:31:05.856Z',
#    'custom_source': None,
#    'eth_address': None,
#    'invited_at': None,
#    'joined_at': None,
#    'phone_number': None,
#    'registered_at': '2025-06-04T11:31:05.856Z',
#    'registration_answers': [{'label': 'Name or Alias',
#      'answer': 'Pancami',
#      'question_id': 'pg6lhrro',
#      'question_type': 'text'},
#     {'label': 'Area of activity in Web3',
#      'answer': 'Japan',
#      'question_id': 'jlm8db1x',
#      'question_type': 'text'},
#     {'label': 'Telegram handle',
#      'answer': '@pancake_crypto0',
#      'question_id': 'vd7qlwtn',
#      'question_type': 'text'},
#     {'label': 'X (Twitter) handle',
#      'answer': '@pancake_crypto0',
#      'question_id': 'j7ohhsuw',
#      'question_type': 'text'},
#     {'label': 'Who invited you?',
#      'answer': 'Ari',
#      'question_id': 'hs5j82g7',
#      'question_type': 'text'}],
#    'solana_address': None,
#    'user_api_id': 'usr-zvGlgt5OZzjVnk5',
#    'user_name': 'Pancami',
#    'user_email': 'rerere_no_ren321@yahoo.co.jp',
#    'user_first_name': 'Pancami',
#    'user_last_name': '',
#    'name': 'Pancami',
#    'email': 'rerere_no_ren321@yahoo.co.jp',
#    'checked_in_at': None,
#    'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-57BarN9wbovToEh',
#    'event_tickets': [{'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-CkPLHjf4f5GzLDQ',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}],
#    'event_ticket': {'amount': 0,
#     'amount_discount': 0,
#     'amount_tax': 0,
#     'api_id': 'eventticket-CkPLHjf4f5GzLDQ',
#     'checked_in_at': None,
#     'currency': 'usd',
#     'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#     'is_captured': False,
#     'name': 'VIP'}}},
#  {'api_id': 'gst-CpqyBigk1ERpGmY',
#   'guest': {'api_id': 'gst-CpqyBigk1ERpGmY',
#    'approval_status': 'approved',
#    'created_at': '2025-06-05T02:40:30.142Z',
#    'custom_source': None,
#    'eth_address': None,
#    'invited_at': None,
#    'joined_at': None,
#    'phone_number': None,
#    'registered_at': '2025-06-05T02:40:30.142Z',
#    'registration_answers': [{'label': 'Name or Alias',
#      'answer': '大石',
#      'question_id': 'pg6lhrro',
#      'question_type': 'text'},
#     {'label': 'Area of activity in Web3',
#      'answer': 'X',
#      'question_id': 'jlm8db1x',
#      'question_type': 'text'},
#     {'label': 'Telegram handle',
#      'answer': '@udonkue',
#      'question_id': 'vd7qlwtn',
#      'question_type': 'text'},
#     {'label': 'X (Twitter) handle',
#      'answer': 'https://x.com/saamon2500',
#      'question_id': 'j7ohhsuw',
#      'question_type': 'text'},
#     {'label': 'Who invited you?',
#      'answer': 'ふにまん',
#      'question_id': 'hs5j82g7',
#      'question_type': 'text'}],
#    'solana_address': None,
#    'user_api_id': 'usr-Y6uTTjgPky0ypBP',
#    'user_name': 'サーモン',
#    'user_email': 'saamon1986@gmail.com',
#    'user_first_name': None,
#    'user_last_name': None,
#    'name': 'サーモン',
#    'email': 'saamon1986@gmail.com',
#    'checked_in_at': None,
#    'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-WoHusBrd9mlJk15',
#    'event_tickets': [{'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-Gv1ayMR1D9ppEWU',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}],
#    'event_ticket': {'amount': 0,
#     'amount_discount': 0,
#     'amount_tax': 0,
#     'api_id': 'eventticket-Gv1ayMR1D9ppEWU',
#     'checked_in_at': None,
#     'currency': 'usd',
#     'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#     'is_captured': False,
#     'name': 'VIP'}}},
#  {'api_id': 'gst-eTXDIqmzXxSK7Vu',
#   'guest': {'api_id': 'gst-eTXDIqmzXxSK7Vu',
#    'approval_status': 'approved',
#    'created_at': '2025-06-05T04:58:34.175Z',
#    'custom_source': None,
#    'eth_address': None,
#    'invited_at': None,
#    'joined_at': None,
#    'phone_number': None,
#    'registered_at': '2025-06-05T04:58:34.175Z',
#    'registration_answers': [{'label': 'Name or Alias',
#      'answer': '@web3_honey',
#      'question_id': 'pg6lhrro',
#      'question_type': 'text'},
#     {'label': 'Area of activity in Web3',
#      'answer': 'all',
#      'question_id': 'jlm8db1x',
#      'question_type': 'text'},
#     {'label': 'Telegram handle',
#      'answer': '@web3_honey',
#      'question_id': 'vd7qlwtn',
#      'question_type': 'text'},
#     {'label': 'X (Twitter) handle',
#      'answer': 'https://x.com/web3_honey',
#      'question_id': 'j7ohhsuw',
#      'question_type': 'text'},
#     {'label': 'Who invited you?',
#      'answer': 'BZB',
#      'question_id': 'hs5j82g7',
#      'question_type': 'text'}],
#    'solana_address': None,
#    'user_api_id': 'usr-wG9rqzWLwONRWDe',
#    'user_name': 'web3honey',
#    'user_email': 'web3honey@buzzbridge.capital',
#    'user_first_name': 'honey',
#    'user_last_name': 'web3',
#    'name': 'web3honey',
#    'email': 'web3honey@buzzbridge.capital',
#    'checked_in_at': None,
#    'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-0TVLQA50dg0FnvA',
#    'event_tickets': [{'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-eBMi8aujOQbP6z5',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}],
#    'event_ticket': {'amount': 0,
#     'amount_discount': 0,
#     'amount_tax': 0,
#     'api_id': 'eventticket-eBMi8aujOQbP6z5',
#     'checked_in_at': None,
#     'currency': 'usd',
#     'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#     'is_captured': False,
#     'name': 'VIP'}}},
#  {'api_id': 'gst-Q1xdehUTZ0Xlfu1',
#   'guest': {'api_id': 'gst-Q1xdehUTZ0Xlfu1',
#    'approval_status': 'approved',
#    'created_at': '2025-06-05T04:58:38.868Z',
#    'custom_source': None,
#    'eth_address': None,
#    'invited_at': None,
#    'joined_at': None,
#    'phone_number': None,
#    'registered_at': '2025-06-05T04:58:38.868Z',
#    'registration_answers': [{'label': 'Name or Alias',
#      'answer': 'hunisan',
#      'question_id': 'pg6lhrro',
#      'question_type': 'text'},
#     {'label': 'Area of activity in Web3',
#      'answer': 'all',
#      'question_id': 'jlm8db1x',
#      'question_type': 'text'},
#     {'label': 'Telegram handle',
#      'answer': 'hunisan',
#      'question_id': 'vd7qlwtn',
#      'question_type': 'text'},
#     {'label': 'X (Twitter) handle',
#      'answer': 'https://x.com/huni_crypto',
#      'question_id': 'j7ohhsuw',
#      'question_type': 'text'},
#     {'label': 'Who invited you?',
#      'answer': 'BZB',
#      'question_id': 'hs5j82g7',
#      'question_type': 'text'}],
#    'solana_address': None,
#    'user_api_id': 'usr-zqyf32Z6JeAroDq',
#    'user_name': 'hunisan',
#    'user_email': 'noboruh@buzzbridge.capital',
#    'user_first_name': 'Hunisan',
#    'user_last_name': 'Hirayama',
#    'name': 'hunisan',
#    'email': 'noboruh@buzzbridge.capital',
#    'checked_in_at': None,
#    'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-tUyEePB0NIXKAfR',
#    'event_tickets': [{'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-4HsAk8035MCuLKx',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}],
#    'event_ticket': {'amount': 0,
#     'amount_discount': 0,
#     'amount_tax': 0,
#     'api_id': 'eventticket-4HsAk8035MCuLKx',
#     'checked_in_at': None,
#     'currency': 'usd',
#     'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#     'is_captured': False,
#     'name': 'VIP'}}},
#  {'api_id': 'gst-d9ZqcbYchSlLrzh',
#   'guest': {'api_id': 'gst-d9ZqcbYchSlLrzh',
#    'approval_status': 'approved',
#    'created_at': '2025-06-05T05:01:41.229Z',
#    'custom_source': None,
#    'eth_address': None,
#    'invited_at': None,
#    'joined_at': None,
#    'phone_number': None,
#    'registered_at': '2025-06-05T05:01:41.228Z',
#    'registration_answers': [{'label': 'Name or Alias',
#      'answer': 'Aki ',
#      'question_id': 'pg6lhrro',
#      'question_type': 'text'},
#     {'label': 'Area of activity in Web3',
#      'answer': 'game',
#      'question_id': 'jlm8db1x',
#      'question_type': 'text'},
#     {'label': 'Telegram handle',
#      'answer': 'Aki_BCG',
#      'question_id': 'vd7qlwtn',
#      'question_type': 'text'},
#     {'label': 'X (Twitter) handle',
#      'answer': 'aki_playaxie',
#      'question_id': 'j7ohhsuw',
#      'question_type': 'text'},
#     {'label': 'Who invited you?',
#      'answer': 'BZB',
#      'question_id': 'hs5j82g7',
#      'question_type': 'text'}],
#    'solana_address': None,
#    'user_api_id': 'usr-BvCCLdjFH8U8gIC',
#    'user_name': 'Aki',
#    'user_email': 'chiaki.goto.kame@gmail.com',
#    'user_first_name': 'Aki',
#    'user_last_name': '',
#    'name': 'Aki',
#    'email': 'chiaki.goto.kame@gmail.com',
#    'checked_in_at': None,
#    'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-M4VB2STvi9kSQjZ',
#    'event_tickets': [{'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-RemIre5XioHoqTs',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}],
#    'event_ticket': {'amount': 0,
#     'amount_discount': 0,
#     'amount_tax': 0,
#     'api_id': 'eventticket-RemIre5XioHoqTs',
#     'checked_in_at': None,
#     'currency': 'usd',
#     'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#     'is_captured': False,
#     'name': 'VIP'}}},
#  {'api_id': 'gst-bGmpnyQkkR2KMMF',
#   'guest': {'api_id': 'gst-bGmpnyQkkR2KMMF',
#    'approval_status': 'approved',
#    'created_at': '2025-06-05T06:32:03.199Z',
#    'custom_source': None,
#    'eth_address': None,
#    'invited_at': None,
#    'joined_at': None,
#    'phone_number': None,
#    'registered_at': '2025-06-05T06:32:03.199Z',
#    'registration_answers': [{'label': 'Name or Alias',
#      'answer': 'Yamasho',
#      'question_id': 'pg6lhrro',
#      'question_type': 'text'},
#     {'label': 'Area of activity in Web3',
#      'answer': 'Web3 Adviser',
#      'question_id': 'jlm8db1x',
#      'question_type': 'text'},
#     {'label': 'Telegram handle',
#      'answer': 'Wink_Three_Yamasho',
#      'question_id': 'vd7qlwtn',
#      'question_type': 'text'},
#     {'label': 'X (Twitter) handle',
#      'answer': 'https://x.com/Yamasho_rivique',
#      'question_id': 'j7ohhsuw',
#      'question_type': 'text'},
#     {'label': 'Who invited you?',
#      'answer': 'BZB',
#      'question_id': 'hs5j82g7',
#      'question_type': 'text'}],
#    'solana_address': None,
#    'user_api_id': 'usr-LCt7o3XoAvewcsV',
#    'user_name': 'Yamasho',
#    'user_email': 'yamasho.wink3@gmail.com',
#    'user_first_name': 'Yamasho',
#    'user_last_name': '',
#    'name': 'Yamasho',
#    'email': 'yamasho.wink3@gmail.com',
#    'checked_in_at': None,
#    'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-mnB1zfSR0qp9Cg5',
#    'event_tickets': [{'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-X8gs6JJBhHFG3BL',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}],
#    'event_ticket': {'amount': 0,
#     'amount_discount': 0,
#     'amount_tax': 0,
#     'api_id': 'eventticket-X8gs6JJBhHFG3BL',
#     'checked_in_at': None,
#     'currency': 'usd',
#     'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#     'is_captured': False,
#     'name': 'VIP'}}},
#  {'api_id': 'gst-UfdXMEWanVxGgBl',
#   'guest': {'api_id': 'gst-UfdXMEWanVxGgBl',
#    'approval_status': 'approved',
#    'created_at': '2025-06-05T10:04:00.170Z',
#    'custom_source': None,
#    'eth_address': None,
#    'invited_at': None,
#    'joined_at': None,
#    'phone_number': None,
#    'registered_at': '2025-06-05T10:04:00.169Z',
#    'registration_answers': [{'label': 'Name or Alias',
#      'answer': 'JP',
#      'question_id': 'pg6lhrro',
#      'question_type': 'text'},
#     {'label': 'Area of activity in Web3',
#      'answer': 'Marketing lead',
#      'question_id': 'jlm8db1x',
#      'question_type': 'text'},
#     {'label': 'Telegram handle',
#      'answer': '@JPIPX',
#      'question_id': 'vd7qlwtn',
#      'question_type': 'text'},
#     {'label': 'X (Twitter) handle',
#      'answer': '@JP_IPX',
#      'question_id': 'j7ohhsuw',
#      'question_type': 'text'},
#     {'label': 'Who invited you?',
#      'answer': 'https://www.linkedin.com/in/ryan-yousang-chin-59598687',
#      'question_id': 'hs5j82g7',
#      'question_type': 'text'}],
#    'solana_address': None,
#    'user_api_id': 'usr-x1R4yL968EVvWpz',
#    'user_name': 'JP',
#    'user_email': 'junpyo.ipx@gmail.com',
#    'user_first_name': 'Junpyo',
#    'user_last_name': 'Lee',
#    'name': 'JP',
#    'email': 'junpyo.ipx@gmail.com',
#    'checked_in_at': None,
#    'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-DmqLgKVgPmnZCeh',
#    'event_tickets': [{'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-4ZCEXwWBlDMQFMG',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}],
#    'event_ticket': {'amount': 0,
#     'amount_discount': 0,
#     'amount_tax': 0,
#     'api_id': 'eventticket-4ZCEXwWBlDMQFMG',
#     'checked_in_at': None,
#     'currency': 'usd',
#     'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#     'is_captured': False,
#     'name': 'VIP'}}},
#  {'api_id': 'gst-D2ggez4iwLmNh0V',
#   'guest': {'api_id': 'gst-D2ggez4iwLmNh0V',
#    'approval_status': 'approved',
#    'created_at': '2025-06-06T02:54:44.931Z',
#    'custom_source': None,
#    'eth_address': None,
#    'invited_at': None,
#    'joined_at': None,
#    'phone_number': None,
#    'registered_at': '2025-06-06T02:54:44.931Z',
#    'registration_answers': [{'label': 'Name or Alias',
#      'answer': 'Saki',
#      'question_id': 'pg6lhrro',
#      'question_type': 'text'},
#     {'label': 'Area of activity in Web3',
#      'answer': 'Media',
#      'question_id': 'jlm8db1x',
#      'question_type': 'text'},
#     {'label': 'Telegram handle',
#      'answer': 'https://t.me/SakiYamamoto',
#      'question_id': 'vd7qlwtn',
#      'question_type': 'text'},
#     {'label': 'X (Twitter) handle',
#      'answer': 'https://x.com/JpCointelegraph',
#      'question_id': 'j7ohhsuw',
#      'question_type': 'text'},
#     {'label': 'Who invited you?',
#      'answer': 'Makoto(Coinpost)',
#      'question_id': 'hs5j82g7',
#      'question_type': 'text'}],
#    'solana_address': None,
#    'user_api_id': 'usr-0j6C4bSjMnMmCci',
#    'user_name': 'Saki',
#    'user_email': 'saki.yamamoto.jp@cointelegraph.com',
#    'user_first_name': 'Saki',
#    'user_last_name': '',
#    'name': 'Saki',
#    'email': 'saki.yamamoto.jp@cointelegraph.com',
#    'checked_in_at': None,
# ...
#      'amount_tax': 0,
#      'api_id': 'eventticket-rl1KnlR2PUT0XDc',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}],
#    'event_ticket': {'amount': 0,
#     'amount_discount': 0,
#     'amount_tax': 0,
#     'api_id': 'eventticket-rl1KnlR2PUT0XDc',
#     'checked_in_at': None,
#     'currency': 'usd',
#     'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#     'is_captured': False,
#     'name': 'VIP'}}},
#  {'api_id': 'gst-05gRxZ2ED4wlWA7',
#   'guest': {'api_id': 'gst-05gRxZ2ED4wlWA7',
#    'approval_status': 'approved',
#    'created_at': '2025-06-08T21:37:42.562Z',
#    'custom_source': None,
#    'eth_address': None,
#    'invited_at': None,
#    'joined_at': None,
#    'phone_number': None,
#    'registered_at': '2025-06-08T21:37:42.561Z',
#    'registration_answers': [{'label': 'Name or Alias',
#      'answer': 'Yuuuuu',
#      'question_id': 'pg6lhrro',
#      'question_type': 'text'},
#     {'label': 'Area of activity in Web3',
#      'answer': 'Game',
#      'question_id': 'jlm8db1x',
#      'question_type': 'text'},
#     {'label': 'Telegram handle',
#      'answer': 'yuu_axielabs',
#      'question_id': 'vd7qlwtn',
#      'question_type': 'text'},
#     {'label': 'X (Twitter) handle',
#      'answer': 'https://x.com/yuu_AxieLabs',
#      'question_id': 'j7ohhsuw',
#      'question_type': 'text'},
#     {'label': 'Who invited you?',
#      'answer': 'Amechan',
#      'question_id': 'hs5j82g7',
#      'question_type': 'text'}],
#    'solana_address': None,
#    'user_api_id': 'usr-8tpdtXtVBCgSth3',
#    'user_name': 'YUUUUU',
#    'user_email': 'yuuuuu@zthreee.net',
#    'user_first_name': 'Yuuuuu',
#    'user_last_name': '',
#    'name': 'YUUUUU',
#    'email': 'yuuuuu@zthreee.net',
#    'checked_in_at': None,
#    'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-pmxCg8xE4DA8NWM',
#    'event_tickets': [{'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-F2BmBga9k5OSvSC',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}],
#    'event_ticket': {'amount': 0,
#     'amount_discount': 0,
#     'amount_tax': 0,
#     'api_id': 'eventticket-F2BmBga9k5OSvSC',
#     'checked_in_at': None,
#     'currency': 'usd',
#     'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#     'is_captured': False,
#     'name': 'VIP'}}},
#  {'api_id': 'gst-YGsfgvEQe4A8vC3',
#   'guest': {'api_id': 'gst-YGsfgvEQe4A8vC3',
#    'approval_status': 'approved',
#    'created_at': '2025-06-08T23:44:05.382Z',
#    'custom_source': None,
#    'eth_address': None,
#    'invited_at': None,
#    'joined_at': None,
#    'phone_number': None,
#    'registered_at': '2025-06-08T23:44:05.382Z',
#    'registration_answers': [{'label': 'Name or Alias',
#      'answer': 'DeFitterジョン',
#      'question_id': 'pg6lhrro',
#      'question_type': 'text'},
#     {'label': 'Area of activity in Web3',
#      'answer': 'BCG/GameFi',
#      'question_id': 'jlm8db1x',
#      'question_type': 'text'},
#     {'label': 'Telegram handle',
#      'answer': 'https://t.me/manman197385',
#      'question_id': 'vd7qlwtn',
#      'question_type': 'text'},
#     {'label': 'X (Twitter) handle',
#      'answer': '@fitter_de',
#      'question_id': 'j7ohhsuw',
#      'question_type': 'text'},
#     {'label': 'Who invited you?',
#      'answer': 'tanukichi',
#      'question_id': 'hs5j82g7',
#      'question_type': 'text'}],
#    'solana_address': None,
#    'user_api_id': 'usr-kvWm1SfWbRL0Ccn',
#    'user_name': 'Defitterジョン',
#    'user_email': 'john@blockchaingame.co.jp',
#    'user_first_name': 'ジョン',
#    'user_last_name': 'Defitter',
#    'name': 'Defitterジョン',
#    'email': 'john@blockchaingame.co.jp',
#    'checked_in_at': None,
#    'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-8AjpMVBpdGKkKeB',
#    'event_tickets': [{'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-XR9pNLmCl3vdAmd',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}],
#    'event_ticket': {'amount': 0,
#     'amount_discount': 0,
#     'amount_tax': 0,
#     'api_id': 'eventticket-XR9pNLmCl3vdAmd',
#     'checked_in_at': None,
#     'currency': 'usd',
#     'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#     'is_captured': False,
#     'name': 'VIP'}}},
#  {'api_id': 'gst-WfEpG73L7w29rWU',
#   'guest': {'api_id': 'gst-WfEpG73L7w29rWU',
#    'approval_status': 'approved',
#    'created_at': '2025-06-09T05:21:37.873Z',
#    'custom_source': None,
#    'eth_address': None,
#    'invited_at': None,
#    'joined_at': None,
#    'phone_number': None,
#    'registered_at': '2025-06-09T05:21:37.872Z',
#    'registration_answers': [{'label': 'Name or Alias',
#      'answer': 'noma',
#      'question_id': 'pg6lhrro',
#      'question_type': 'text'},
#     {'label': 'Area of activity in Web3',
#      'answer': 'BCG',
#      'question_id': 'jlm8db1x',
#      'question_type': 'text'},
#     {'label': 'Telegram handle',
#      'answer': 'n0ma_nn',
#      'question_id': 'vd7qlwtn',
#      'question_type': 'text'},
#     {'label': 'X (Twitter) handle',
#      'answer': '_n0ma',
#      'question_id': 'j7ohhsuw',
#      'question_type': 'text'},
#     {'label': 'Who invited you?',
#      'answer': 'BZB',
#      'question_id': 'hs5j82g7',
#      'question_type': 'text'}],
#    'solana_address': None,
#    'user_api_id': 'usr-p6m4uZn0kqe5mFU',
#    'user_name': 'noma',
#    'user_email': 'noma.zenz00@gmail.com',
#    'user_first_name': 'Noma',
#    'user_last_name': '',
#    'name': 'noma',
#    'email': 'noma.zenz00@gmail.com',
#    'checked_in_at': None,
#    'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-HDpsjNg4FNZqpYw',
#    'event_tickets': [{'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-cuxR39wG2a7aWnQ',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}],
#    'event_ticket': {'amount': 0,
#     'amount_discount': 0,
#     'amount_tax': 0,
#     'api_id': 'eventticket-cuxR39wG2a7aWnQ',
#     'checked_in_at': None,
#     'currency': 'usd',
#     'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#     'is_captured': False,
#     'name': 'VIP'}}},
#  {'api_id': 'gst-nYzS07z4KpBE2Z3',
#   'guest': {'api_id': 'gst-nYzS07z4KpBE2Z3',
#    'approval_status': 'approved',
#    'created_at': '2025-06-09T07:15:26.100Z',
#    'custom_source': None,
#    'eth_address': None,
#    'invited_at': None,
#    'joined_at': None,
#    'phone_number': None,
#    'registered_at': '2025-06-09T07:15:26.099Z',
#    'registration_answers': [{'label': 'Name or Alias',
#      'answer': 'zoku',
#      'question_id': 'pg6lhrro',
#      'question_type': 'text'},
#     {'label': 'Area of activity in Web3',
#      'answer': 'BCG User',
#      'question_id': 'jlm8db1x',
#      'question_type': 'text'},
#     {'label': 'Telegram handle',
#      'answer': 'zoku_chandayo',
#      'question_id': 'vd7qlwtn',
#      'question_type': 'text'},
#     {'label': 'X (Twitter) handle',
#      'answer': 'elf_yamasters',
#      'question_id': 'j7ohhsuw',
#      'question_type': 'text'},
#     {'label': 'Who invited you?',
#      'answer': 'BZB',
#      'question_id': 'hs5j82g7',
#      'question_type': 'text'}],
#    'solana_address': None,
#    'user_api_id': 'usr-3yuqYo2suOm0WDV',
#    'user_name': 'ぞく',
#    'user_email': 'yamaryou112@gmail.com',
#    'user_first_name': '',
#    'user_last_name': '',
#    'name': 'ぞく',
#    'email': 'yamaryou112@gmail.com',
#    'checked_in_at': None,
#    'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-ucQu1bDEAc1Ys4F',
#    'event_tickets': [{'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-FdvBMBfFLwBwDQL',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}],
#    'event_ticket': {'amount': 0,
#     'amount_discount': 0,
#     'amount_tax': 0,
#     'api_id': 'eventticket-FdvBMBfFLwBwDQL',
#     'checked_in_at': None,
#     'currency': 'usd',
#     'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#     'is_captured': False,
#     'name': 'VIP'}}},
#  {'api_id': 'gst-Csm9M5cCBRW4W4B',
#   'guest': {'api_id': 'gst-Csm9M5cCBRW4W4B',
#    'approval_status': 'approved',
#    'created_at': '2025-06-09T07:29:33.595Z',
#    'custom_source': None,
#    'eth_address': None,
#    'invited_at': None,
#    'joined_at': None,
#    'phone_number': None,
#    'registered_at': '2025-06-09T07:29:33.595Z',
#    'registration_answers': [{'label': 'Name or Alias',
#      'answer': 'goose',
#      'question_id': 'pg6lhrro',
#      'question_type': 'text'},
#     {'label': 'Area of activity in Web3',
#      'answer': 'BCG and DeFi',
#      'question_id': 'jlm8db1x',
#      'question_type': 'text'},
#     {'label': 'Telegram handle',
#      'answer': 'teikokubank',
#      'question_id': 'vd7qlwtn',
#      'question_type': 'text'},
#     {'label': 'X (Twitter) handle',
#      'answer': 'teikokubank',
#      'question_id': 'j7ohhsuw',
#      'question_type': 'text'},
#     {'label': 'Who invited you?',
#      'answer': 'BZB',
#      'question_id': 'hs5j82g7',
#      'question_type': 'text'}],
#    'solana_address': None,
#    'user_api_id': 'usr-MOSmsJOprBg4eS9',
#    'user_name': 'goose',
#    'user_email': 'imperialgooose@gmail.com',
#    'user_first_name': None,
#    'user_last_name': None,
#    'name': 'goose',
#    'email': 'imperialgooose@gmail.com',
#    'checked_in_at': None,
#    'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-YChCZ2UFUgqgvkk',
#    'event_tickets': [{'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-p0JLDjH8Zq1y2iv',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}],
#    'event_ticket': {'amount': 0,
#     'amount_discount': 0,
#     'amount_tax': 0,
#     'api_id': 'eventticket-p0JLDjH8Zq1y2iv',
#     'checked_in_at': None,
#     'currency': 'usd',
#     'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#     'is_captured': False,
#     'name': 'VIP'}}},
#  {'api_id': 'gst-E87bdL3SB2wyBY0',
#   'guest': {'api_id': 'gst-E87bdL3SB2wyBY0',
#    'approval_status': 'approved',
#    'created_at': '2025-06-09T10:00:31.679Z',
#    'custom_source': None,
#    'eth_address': None,
#    'invited_at': None,
#    'joined_at': None,
#    'phone_number': None,
#    'registered_at': '2025-06-09T10:00:31.679Z',
#    'registration_answers': [{'label': 'Name or Alias',
#      'answer': 'Yano Taiga',
#      'question_id': 'pg6lhrro',
#      'question_type': 'text'},
#     {'label': 'Area of activity in Web3',
#      'answer': 'Marketplace and Crypto exchange',
#      'question_id': 'jlm8db1x',
#      'question_type': 'text'},
#     {'label': 'Telegram handle',
#      'answer': '@taigamercari',
#      'question_id': 'vd7qlwtn',
#      'question_type': 'text'},
#     {'label': 'X (Twitter) handle',
#      'answer': 'https://x.com/NFT_taiga',
#      'question_id': 'j7ohhsuw',
#      'question_type': 'text'},
#     {'label': 'Who invited you?',
#      'answer': 'BZB',
#      'question_id': 'hs5j82g7',
#      'question_type': 'text'}],
#    'solana_address': None,
#    'user_api_id': 'usr-P1rCnjP3tXYQo9o',
#    'user_name': 'Yano Taiga',
#    'user_email': 'taigayano1@gmail.com',
#    'user_first_name': 'Yano',
#    'user_last_name': 'Taiga',
#    'name': 'Yano Taiga',
#    'email': 'taigayano1@gmail.com',
#    'checked_in_at': None,
#    'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-PryRJSASFWjbfDO',
#    'event_tickets': [{'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-uM1Xo2HMAG73J8Z',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}],
#    'event_ticket': {'amount': 0,
#     'amount_discount': 0,
#     'amount_tax': 0,
#     'api_id': 'eventticket-uM1Xo2HMAG73J8Z',
#     'checked_in_at': None,
#     'currency': 'usd',
#     'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#     'is_captured': False,
#     'name': 'VIP'}}},
#  {'api_id': 'gst-ZLXc1obs0Rp6L2X',
#   'guest': {'api_id': 'gst-ZLXc1obs0Rp6L2X',
#    'approval_status': 'approved',
#    'created_at': '2025-06-09T11:29:51.069Z',
#    'custom_source': None,
#    'eth_address': None,
#    'invited_at': None,
#    'joined_at': None,
#    'phone_number': None,
#    'registered_at': '2025-06-09T11:29:51.069Z',
#    'registration_answers': [{'label': 'Name or Alias',
#      'answer': 'Tomoya',
#      'question_id': 'pg6lhrro',
#      'question_type': 'text'},
#     {'label': 'Area of activity in Web3',
#      'answer': 'BCG',
#      'question_id': 'jlm8db1x',
#      'question_type': 'text'},
#     {'label': 'Telegram handle',
#      'answer': '@tomoya1109',
#      'question_id': 'vd7qlwtn',
#      'question_type': 'text'},
#     {'label': 'X (Twitter) handle',
#      'answer': '@tomoya_11109',
#      'question_id': 'j7ohhsuw',
#      'question_type': 'text'},
#     {'label': 'Who invited you?',
#      'answer': 'BuzzBridgeCapital',
#      'question_id': 'hs5j82g7',
#      'question_type': 'text'}],
#    'solana_address': None,
#    'user_api_id': 'usr-HCfIssbdOKA4vCm',
#    'user_name': 'tomoya',
#    'user_email': 'tomoya@kreation.jp',
#    'user_first_name': None,
#    'user_last_name': None,
#    'name': 'tomoya',
#    'email': 'tomoya@kreation.jp',
#    'checked_in_at': None,
#    'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-cz8qpYD5BMMhAAG',
#    'event_tickets': [{'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-KYprvXC2G3BJ87G',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}],
#    'event_ticket': {'amount': 0,
#     'amount_discount': 0,
#     'amount_tax': 0,
#     'api_id': 'eventticket-KYprvXC2G3BJ87G',
#     'checked_in_at': None,
#     'currency': 'usd',
#     'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#     'is_captured': False,
#     'name': 'VIP'}}},
#  {'api_id': 'gst-r0sOAiyeZwBuk2Y',
#   'guest': {'api_id': 'gst-r0sOAiyeZwBuk2Y',
#    'approval_status': 'approved',
#    'created_at': '2025-06-09T13:44:52.022Z',
#    'custom_source': None,
#    'eth_address': None,
#    'invited_at': None,
#    'joined_at': None,
#    'phone_number': None,
#    'registered_at': '2025-06-09T13:44:52.021Z',
#    'registration_answers': [{'label': 'Name or Alias',
#      'answer': 'fooomin',
#      'question_id': 'pg6lhrro',
#      'question_type': 'text'},
#     {'label': 'Area of activity in Web3',
#      'answer': 'KOL',
#      'question_id': 'jlm8db1x',
#      'question_type': 'text'},
#     {'label': 'Telegram handle',
#      'answer': 'fooomin',
#      'question_id': 'vd7qlwtn',
#      'question_type': 'text'},
#     {'label': 'X (Twitter) handle',
#      'answer': 'https://x.com/fooomin_crypto',
#      'question_id': 'j7ohhsuw',
#      'question_type': 'text'},
#     {'label': 'Who invited you?',
#      'answer': 'BuzzBrideCapital',
#      'question_id': 'hs5j82g7',
#      'question_type': 'text'}],
#    'solana_address': None,
#    'user_api_id': 'usr-Y1G0cFWSuKmWC5E',
#    'user_name': 'フーミン',
#    'user_email': 'knot.blgs@gmail.com',
#    'user_first_name': 'fooomin',
#    'user_last_name': '',
#    'name': 'フーミン',
#    'email': 'knot.blgs@gmail.com',
#    'checked_in_at': None,
#    'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-dQog58wlWBscfJf',
#    'event_tickets': [{'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-7cXl61CTK9wLJUY',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}],
#    'event_ticket': {'amount': 0,
#     'amount_discount': 0,
#     'amount_tax': 0,
#     'api_id': 'eventticket-7cXl61CTK9wLJUY',
#     'checked_in_at': None,
#     'currency': 'usd',
#     'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#     'is_captured': False,
#     'name': 'VIP'}}}]

# %%
guests_url = "https://api.lu.ma/public/v1/event/get-guests"
params = {
    "event_api_id": 'evt-RnsFFJW6vE8tFnQ',
    "approval_status": "approved"
}

response = requests.get(guests_url, headers=headers, params=params)
if response.status_code == 200:
    data = response.json()

# %%
data
# Out:
# {'entries': [{'api_id': 'gst-2xnNgcCT83aKPzj',
#    'guest': {'api_id': 'gst-2xnNgcCT83aKPzj',
#     'approval_status': 'approved',
#     'created_at': '2025-05-30T16:01:55.294Z',
#     'custom_source': None,
#     'eth_address': None,
#     'invited_at': None,
#     'joined_at': None,
#     'phone_number': None,
#     'registered_at': '2025-05-30T16:01:55.293Z',
#     'registration_answers': [{'label': 'Name or Alias',
#       'answer': 'Amechan',
#       'question_id': 'pg6lhrro',
#       'question_type': 'text'},
#      {'label': 'Area of activity in Web3',
#       'answer': 'Marketing',
#       'question_id': 'jlm8db1x',
#       'question_type': 'text'},
#      {'label': 'Telegram handle',
#       'answer': 'web3ame',
#       'question_id': 'vd7qlwtn',
#       'question_type': 'text'},
#      {'label': 'X (Twitter) handle',
#       'answer': 'https://x.com/kawaiigirlnft',
#       'question_id': 'j7ohhsuw',
#       'question_type': 'text'},
#      {'label': 'Who invited you?',
#       'answer': 'BZB',
#       'question_id': 'hs5j82g7',
#       'question_type': 'text'}],
#     'solana_address': None,
#     'user_api_id': 'usr-VPvpKzwiGIA27oZ',
#     'user_name': 'Ame-chan',
#     'user_email': 'amechan@buzzbridge.capital',
#     'user_first_name': 'Ame',
#     'user_last_name': 'Chan',
#     'name': 'Ame-chan',
#     'email': 'amechan@buzzbridge.capital',
#     'checked_in_at': None,
#     'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-0tUvj7EDvDyl7hJ',
#     'event_tickets': [{'amount': 0,
#       'amount_discount': 0,
#       'amount_tax': 0,
#       'api_id': 'eventticket-ncYM6hlyiO1sF49',
#       'checked_in_at': None,
#       'currency': 'usd',
#       'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#       'is_captured': False,
#       'name': 'VIP'}],
#     'event_ticket': {'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-ncYM6hlyiO1sF49',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}}},
#   {'api_id': 'gst-n7dvxo5DnG8VuRg',
#    'guest': {'api_id': 'gst-n7dvxo5DnG8VuRg',
#     'approval_status': 'approved',
#     'created_at': '2025-06-03T16:30:17.647Z',
#     'custom_source': None,
#     'eth_address': None,
#     'invited_at': None,
#     'joined_at': None,
#     'phone_number': None,
#     'registered_at': '2025-06-03T16:30:17.646Z',
#     'registration_answers': [{'label': 'Name or Alias',
#       'answer': 'taka.eth',
#       'question_id': 'pg6lhrro',
#       'question_type': 'text'},
#      {'label': 'Area of activity in Web3',
#       'answer': 'Community builder',
#       'question_id': 'jlm8db1x',
#       'question_type': 'text'},
#      {'label': 'Telegram handle',
#       'answer': 'taka_eth',
#       'question_id': 'vd7qlwtn',
#       'question_type': 'text'},
#      {'label': 'X (Twitter) handle',
#       'answer': 'https://x.com/taka_eth',
#       'question_id': 'j7ohhsuw',
#       'question_type': 'text'},
#      {'label': 'Who invited you?',
#       'answer': 'BZB',
#       'question_id': 'hs5j82g7',
#       'question_type': 'text'}],
#     'solana_address': None,
#     'user_api_id': 'usr-H1TErLDY4NCGLgr',
#     'user_name': 'taka.eth',
#     'user_email': 'taka@boardingbridge.org',
#     'user_first_name': ' ',
#     'user_last_name': 'taka.eth',
#     'name': 'taka.eth',
#     'email': 'taka@boardingbridge.org',
#     'checked_in_at': None,
#     'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-ROKVAcVEBlTLfOO',
#     'event_tickets': [{'amount': 0,
#       'amount_discount': 0,
#       'amount_tax': 0,
#       'api_id': 'eventticket-tYwnooQy4a4gr1g',
#       'checked_in_at': None,
#       'currency': 'usd',
#       'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#       'is_captured': False,
#       'name': 'VIP'}],
#     'event_ticket': {'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-tYwnooQy4a4gr1g',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}}},
#   {'api_id': 'gst-6dU1rcEGEg5yxWQ',
#    'guest': {'api_id': 'gst-6dU1rcEGEg5yxWQ',
#     'approval_status': 'approved',
#     'created_at': '2025-06-03T16:31:51.146Z',
#     'custom_source': None,
#     'eth_address': None,
#     'invited_at': None,
#     'joined_at': None,
#     'phone_number': None,
#     'registered_at': '2025-06-03T16:31:51.145Z',
#     'registration_answers': [{'label': 'Name or Alias',
#       'answer': 'Yokota Shogo',
#       'question_id': 'pg6lhrro',
#       'question_type': 'text'},
#      {'label': 'Area of activity in Web3',
#       'answer': 'NFT GAME',
#       'question_id': 'jlm8db1x',
#       'question_type': 'text'},
#      {'label': 'Telegram handle',
#       'answer': 'goshou1031',
#       'question_id': 'vd7qlwtn',
#       'question_type': 'text'},
#      {'label': 'X (Twitter) handle',
#       'answer': 'https://x.com/gosho1031',
#       'question_id': 'j7ohhsuw',
#       'question_type': 'text'},
#      {'label': 'Who invited you?',
#       'answer': 'WEB3HONEY',
#       'question_id': 'hs5j82g7',
#       'question_type': 'text'}],
#     'solana_address': None,
#     'user_api_id': 'usr-u1raz4KVRVGUzAd',
#     'user_name': '横田昇吾',
#     'user_email': 's.yokota@blockchaingame.co.jp',
#     'user_first_name': '昇吾',
#     'user_last_name': '横田',
#     'name': '横田昇吾',
#     'email': 's.yokota@blockchaingame.co.jp',
#     'checked_in_at': None,
#     'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-U9oK5Pm4paOHaXK',
#     'event_tickets': [{'amount': 0,
#       'amount_discount': 0,
#       'amount_tax': 0,
#       'api_id': 'eventticket-yLUhg3J1WXZkBNx',
#       'checked_in_at': None,
#       'currency': 'usd',
#       'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#       'is_captured': False,
#       'name': 'VIP'}],
#     'event_ticket': {'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-yLUhg3J1WXZkBNx',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}}},
#   {'api_id': 'gst-lKAPeXk0Or4USZz',
#    'guest': {'api_id': 'gst-lKAPeXk0Or4USZz',
#     'approval_status': 'approved',
#     'created_at': '2025-06-03T16:42:09.788Z',
#     'custom_source': None,
#     'eth_address': None,
#     'invited_at': None,
#     'joined_at': None,
#     'phone_number': None,
#     'registered_at': '2025-06-03T16:42:09.787Z',
#     'registration_answers': [{'label': 'Name or Alias',
#       'answer': 'NOROI GAMIES',
#       'question_id': 'pg6lhrro',
#       'question_type': 'text'},
#      {'label': 'Area of activity in Web3',
#       'answer': 'Web3 Gaming',
#       'question_id': 'jlm8db1x',
#       'question_type': 'text'},
#      {'label': 'Telegram handle',
#       'answer': 'noroichan_game',
#       'question_id': 'vd7qlwtn',
#       'question_type': 'text'},
#      {'label': 'X (Twitter) handle',
#       'answer': 'https://x.com/noroichan_game',
#       'question_id': 'j7ohhsuw',
#       'question_type': 'text'},
#      {'label': 'Who invited you?',
#       'answer': 'BZB',
#       'question_id': 'hs5j82g7',
#       'question_type': 'text'}],
#     'solana_address': None,
#     'user_api_id': 'usr-wMAwE3xnBXRyDuZ',
#     'user_name': 'NOROI',
#     'user_email': 'noroichan.m@gmail.com',
#     'user_first_name': 'ちゃん',
#     'user_last_name': 'のろい',
#     'name': 'NOROI',
#     'email': 'noroichan.m@gmail.com',
#     'checked_in_at': None,
#     'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-g2ndJ8ljhXUpHJe',
#     'event_tickets': [{'amount': 0,
#       'amount_discount': 0,
#       'amount_tax': 0,
#       'api_id': 'eventticket-GaqNlk5Hy18bPKA',
#       'checked_in_at': None,
#       'currency': 'usd',
#       'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#       'is_captured': False,
#       'name': 'VIP'}],
#     'event_ticket': {'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-GaqNlk5Hy18bPKA',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}}},
#   {'api_id': 'gst-Ae1sHVWeK47YuBC',
#    'guest': {'api_id': 'gst-Ae1sHVWeK47YuBC',
#     'approval_status': 'approved',
#     'created_at': '2025-06-03T16:49:40.823Z',
#     'custom_source': None,
#     'eth_address': None,
#     'invited_at': None,
#     'joined_at': None,
#     'phone_number': None,
#     'registered_at': '2025-06-03T16:49:40.823Z',
#     'registration_answers': [{'label': 'Name or Alias',
#       'answer': 'Makoto Aoki',
#       'question_id': 'pg6lhrro',
#       'question_type': 'text'},
#      {'label': 'Area of activity in Web3',
#       'answer': 'Media',
#       'question_id': 'jlm8db1x',
#       'question_type': 'text'},
#      {'label': 'Telegram handle',
#       'answer': 'Makoto_CoinPost',
#       'question_id': 'vd7qlwtn',
#       'question_type': 'text'},
#      {'label': 'X (Twitter) handle',
#       'answer': 'https://x.com/Makoto_CoinPost',
#       'question_id': 'j7ohhsuw',
#       'question_type': 'text'},
#      {'label': 'Who invited you?',
#       'answer': 'BZB',
#       'question_id': 'hs5j82g7',
#       'question_type': 'text'}],
#     'solana_address': None,
#     'user_api_id': 'usr-47JhC2ApRSL5GCa',
#     'user_name': 'Makoto Aoki',
#     'user_email': 'a.makoto@coinpost.jp',
#     'user_first_name': 'Makoto',
#     'user_last_name': 'Aoki',
#     'name': 'Makoto Aoki',
#     'email': 'a.makoto@coinpost.jp',
#     'checked_in_at': None,
#     'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-eCEQpETNcblEWX7',
#     'event_tickets': [{'amount': 0,
#       'amount_discount': 0,
#       'amount_tax': 0,
#       'api_id': 'eventticket-ve8GrUaBEVcthPm',
#       'checked_in_at': None,
#       'currency': 'usd',
#       'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#       'is_captured': False,
#       'name': 'VIP'}],
#     'event_ticket': {'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-ve8GrUaBEVcthPm',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}}},
#   {'api_id': 'gst-108JcQnXyfbU408',
#    'guest': {'api_id': 'gst-108JcQnXyfbU408',
#     'approval_status': 'approved',
#     'created_at': '2025-06-03T17:02:36.717Z',
#     'custom_source': None,
#     'eth_address': None,
#     'invited_at': None,
#     'joined_at': None,
#     'phone_number': None,
#     'registered_at': '2025-06-03T17:02:36.715Z',
#     'registration_answers': [{'label': 'Name or Alias',
#       'answer': 'Luin Aozora',
#       'question_id': 'pg6lhrro',
#       'question_type': 'text'},
#      {'label': 'Area of activity in Web3',
#       'answer': 'Web3 Game',
#       'question_id': 'jlm8db1x',
#       'question_type': 'text'},
#      {'label': 'Telegram handle',
#       'answer': 'luin_aozora',
#       'question_id': 'vd7qlwtn',
#       'question_type': 'text'},
#      {'label': 'X (Twitter) handle',
#       'answer': '@luin_aozora',
#       'question_id': 'j7ohhsuw',
#       'question_type': 'text'},
#      {'label': 'Who invited you?',
#       'answer': 'BZB',
#       'question_id': 'hs5j82g7',
#       'question_type': 'text'}],
#     'solana_address': None,
#     'user_api_id': 'usr-3VVwVtLkjgLPMcG',
#     'user_name': 'Luin Aozora',
#     'user_email': 'luin.aozora@gmail.com',
#     'user_first_name': 'Luin',
#     'user_last_name': 'Aozora',
#     'name': 'Luin Aozora',
#     'email': 'luin.aozora@gmail.com',
#     'checked_in_at': None,
#     'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-Tv3Vsz2dUQQC2Eb',
#     'event_tickets': [{'amount': 0,
#       'amount_discount': 0,
#       'amount_tax': 0,
#       'api_id': 'eventticket-yX9MEb6YTPW78Wj',
#       'checked_in_at': None,
#       'currency': 'usd',
#       'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#       'is_captured': False,
#       'name': 'VIP'}],
#     'event_ticket': {'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-yX9MEb6YTPW78Wj',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}}},
#   {'api_id': 'gst-AGAUmv3Gu46sXSx',
#    'guest': {'api_id': 'gst-AGAUmv3Gu46sXSx',
#     'approval_status': 'approved',
#     'created_at': '2025-06-03T17:05:11.549Z',
#     'custom_source': None,
#     'eth_address': None,
#     'invited_at': None,
#     'joined_at': None,
#     'phone_number': None,
#     'registered_at': '2025-06-03T17:05:11.549Z',
#     'registration_answers': [{'label': 'Name or Alias',
#       'answer': 'Aku',
#       'question_id': 'pg6lhrro',
#       'question_type': 'text'},
#      {'label': 'Area of activity in Web3',
#       'answer': 'KOL',
#       'question_id': 'jlm8db1x',
#       'question_type': 'text'},
#      {'label': 'Telegram handle',
#       'answer': '@aku00aku',
#       'question_id': 'vd7qlwtn',
#       'question_type': 'text'},
#      {'label': 'X (Twitter) handle',
#       'answer': '@A4lLfa7',
#       'question_id': 'j7ohhsuw',
#       'question_type': 'text'},
#      {'label': 'Who invited you?',
#       'answer': 'BZB',
#       'question_id': 'hs5j82g7',
#       'question_type': 'text'}],
#     'solana_address': None,
#     'user_api_id': 'usr-B0Zz1UXBcpuJybU',
#     'user_name': 'Aku',
#     'user_email': 'amoonlight8558@gmail.com',
#     'user_first_name': 'Aku',
#     'user_last_name': '',
#     'name': 'Aku',
#     'email': 'amoonlight8558@gmail.com',
#     'checked_in_at': None,
#     'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-DiNKOywbLbTgkTv',
#     'event_tickets': [{'amount': 0,
#       'amount_discount': 0,
#       'amount_tax': 0,
#       'api_id': 'eventticket-uzgKRNvsnvnrLOg',
#       'checked_in_at': None,
#       'currency': 'usd',
#       'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#       'is_captured': False,
#       'name': 'VIP'}],
#     'event_ticket': {'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-uzgKRNvsnvnrLOg',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}}},
#   {'api_id': 'gst-RDMFWOqY3uO1Ok1',
#    'guest': {'api_id': 'gst-RDMFWOqY3uO1Ok1',
#     'approval_status': 'approved',
#     'created_at': '2025-06-03T19:43:16.061Z',
#     'custom_source': None,
#     'eth_address': None,
#     'invited_at': None,
#     'joined_at': None,
#     'phone_number': None,
#     'registered_at': '2025-06-03T19:43:16.061Z',
#     'registration_answers': [{'label': 'Name or Alias',
#       'answer': 'Akira Komiya',
#       'question_id': 'pg6lhrro',
#       'question_type': 'text'},
#      {'label': 'Area of activity in Web3',
#       'answer': 'Japan',
#       'question_id': 'jlm8db1x',
#       'question_type': 'text'},
#      {'label': 'Telegram handle',
#       'answer': 'akirakomiyas',
#       'question_id': 'vd7qlwtn',
#       'question_type': 'text'},
#      {'label': 'X (Twitter) handle',
#       'answer': 'komiya5395',
#       'question_id': 'j7ohhsuw',
#       'question_type': 'text'},
#      {'label': 'Who invited you?',
#       'answer': 'BZB',
#       'question_id': 'hs5j82g7',
#       'question_type': 'text'}],
#     'solana_address': None,
#     'user_api_id': 'usr-01GBNOJcTGhJ0JU',
#     'user_name': 'NinjaGuild_Japan (NGG)',
#     'user_email': 'akira.komiya@guild.support',
#     'user_first_name': None,
#     'user_last_name': None,
#     'name': 'NinjaGuild_Japan (NGG)',
#     'email': 'akira.komiya@guild.support',
#     'checked_in_at': None,
#     'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-Gprf3Sf23cvXtaD',
#     'event_tickets': [{'amount': 0,
#       'amount_discount': 0,
#       'amount_tax': 0,
#       'api_id': 'eventticket-C06np7lhuMVrvVF',
#       'checked_in_at': None,
#       'currency': 'usd',
#       'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#       'is_captured': False,
#       'name': 'VIP'}],
#     'event_ticket': {'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-C06np7lhuMVrvVF',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}}},
#   {'api_id': 'gst-dYR55msypgRdXgG',
#    'guest': {'api_id': 'gst-dYR55msypgRdXgG',
#     'approval_status': 'approved',
#     'created_at': '2025-06-03T20:34:51.298Z',
#     'custom_source': None,
#     'eth_address': None,
#     'invited_at': None,
#     'joined_at': None,
#     'phone_number': None,
#     'registered_at': '2025-06-03T20:34:51.297Z',
#     'registration_answers': [{'label': 'Name or Alias',
#       'answer': 'チビクロ｜CSO - ISC',
#       'question_id': 'pg6lhrro',
#       'question_type': 'text'},
#      {'label': 'Area of activity in Web3',
#       'answer': 'KOL',
#       'question_id': 'jlm8db1x',
#       'question_type': 'text'},
#      {'label': 'Telegram handle',
#       'answer': '@Chibikuro4741',
#       'question_id': 'vd7qlwtn',
#       'question_type': 'text'},
#      {'label': 'X (Twitter) handle',
#       'answer': 'https://x.com/CHIBIKURO_QnQ',
#       'question_id': 'j7ohhsuw',
#       'question_type': 'text'},
#      {'label': 'Who invited you?',
#       'answer': 'BZB',
#       'question_id': 'hs5j82g7',
#       'question_type': 'text'}],
#     'solana_address': None,
#     'user_api_id': 'usr-7xXLkoTRAjixKk2',
#     'user_name': 'チビクロ｜CSO - ISC',
#     'user_email': 'tensyu9@gmail.com',
#     'user_first_name': '耕平',
#     'user_last_name': '山下',
#     'name': 'チビクロ｜CSO - ISC',
#     'email': 'tensyu9@gmail.com',
#     'checked_in_at': None,
#     'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-J8vi0OjG7IKWv1D',
#     'event_tickets': [{'amount': 0,
#       'amount_discount': 0,
#       'amount_tax': 0,
#       'api_id': 'eventticket-oLF8VdeHGSwDNGc',
#       'checked_in_at': None,
#       'currency': 'usd',
#       'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#       'is_captured': False,
#       'name': 'VIP'}],
#     'event_ticket': {'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-oLF8VdeHGSwDNGc',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}}},
#   {'api_id': 'gst-gQrCFkNCdw5tHXj',
#    'guest': {'api_id': 'gst-gQrCFkNCdw5tHXj',
#     'approval_status': 'approved',
#     'created_at': '2025-06-03T22:46:39.487Z',
#     'custom_source': None,
#     'eth_address': None,
#     'invited_at': None,
#     'joined_at': None,
#     'phone_number': None,
#     'registered_at': '2025-06-03T22:46:39.486Z',
#     'registration_answers': [{'label': 'Name or Alias',
#       'answer': 'gaccho',
#       'question_id': 'pg6lhrro',
#       'question_type': 'text'},
#      {'label': 'Area of activity in Web3',
#       'answer': 'X',
#       'question_id': 'jlm8db1x',
#       'question_type': 'text'},
#      {'label': 'Telegram handle',
#       'answer': '@Gaccho_0622',
#       'question_id': 'vd7qlwtn',
#       'question_type': 'text'},
#      {'label': 'X (Twitter) handle',
#       'answer': 'https://x.com/daice_0622',
#       'question_id': 'j7ohhsuw',
#       'question_type': 'text'},
#      {'label': 'Who invited you?',
#       'answer': 'たぬきちさん',
#       'question_id': 'hs5j82g7',
#       'question_type': 'text'}],
#     'solana_address': None,
#     'user_api_id': 'usr-15yUoQI9PiocL3a',
#     'user_name': 'Gaccho',
#     'user_email': 'kotiya6622@gmail.com',
#     'user_first_name': 'Gaccho',
#     'user_last_name': '',
#     'name': 'Gaccho',
#     'email': 'kotiya6622@gmail.com',
#     'checked_in_at': None,
#     'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-rKJbVUwZu3bKSPi',
#     'event_tickets': [{'amount': 0,
#       'amount_discount': 0,
#       'amount_tax': 0,
#       'api_id': 'eventticket-UyExC7BoatQebee',
#       'checked_in_at': None,
#       'currency': 'usd',
#       'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#       'is_captured': False,
#       'name': 'VIP'}],
#     'event_ticket': {'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-UyExC7BoatQebee',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}}},
#   {'api_id': 'gst-pcrZGsYemAIKIyd',
#    'guest': {'api_id': 'gst-pcrZGsYemAIKIyd',
#     'approval_status': 'approved',
#     'created_at': '2025-06-04T01:24:05.408Z',
#     'custom_source': None,
#     'eth_address': None,
#     'invited_at': None,
#     'joined_at': None,
#     'phone_number': None,
#     'registered_at': '2025-06-04T01:24:05.407Z',
#     'registration_answers': [{'label': 'Name or Alias',
#       'answer': 'AEB',
#       'question_id': 'pg6lhrro',
#       'question_type': 'text'},
#      {'label': 'Area of activity in Web3',
#       'answer': 'NFT',
#       'question_id': 'jlm8db1x',
#       'question_type': 'text'},
#      {'label': 'Telegram handle',
#       'answer': 'BUN AEB',
#       'question_id': 'vd7qlwtn',
#       'question_type': 'text'},
#      {'label': 'X (Twitter) handle',
#       'answer': 'https://x.com/aeb_nft',
#       'question_id': 'j7ohhsuw',
#       'question_type': 'text'},
#      {'label': 'Who invited you?',
#       'answer': 'BZB',
#       'question_id': 'hs5j82g7',
#       'question_type': 'text'}],
#     'solana_address': None,
#     'user_api_id': 'usr-lbOEWmpG1Xjom7T',
#     'user_name': 'A.E.B／BUN',
#     'user_email': 'aeb@whereverse.jp',
#     'user_first_name': '翔太',
#     'user_last_name': '國分',
#     'name': 'A.E.B／BUN',
#     'email': 'aeb@whereverse.jp',
#     'checked_in_at': None,
#     'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-UYLttEaFwzawze3',
#     'event_tickets': [{'amount': 0,
#       'amount_discount': 0,
#       'amount_tax': 0,
#       'api_id': 'eventticket-97TAodZqSkHG3mb',
#       'checked_in_at': None,
#       'currency': 'usd',
#       'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#       'is_captured': False,
#       'name': 'VIP'}],
#     'event_ticket': {'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-97TAodZqSkHG3mb',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}}},
#   {'api_id': 'gst-UByS7xbRVO9jAij',
#    'guest': {'api_id': 'gst-UByS7xbRVO9jAij',
#     'approval_status': 'approved',
#     'created_at': '2025-06-04T03:01:33.553Z',
#     'custom_source': None,
#     'eth_address': None,
#     'invited_at': None,
#     'joined_at': None,
#     'phone_number': None,
#     'registered_at': '2025-06-04T03:01:33.553Z',
#     'registration_answers': [{'label': 'Name or Alias',
#       'answer': 'you425',
#       'question_id': 'pg6lhrro',
#       'question_type': 'text'},
#      {'label': 'Area of activity in Web3',
#       'answer': 'Researcher',
#       'question_id': 'jlm8db1x',
#       'question_type': 'text'},
#      {'label': 'Telegram handle',
#       'answer': 'you425',
#       'question_id': 'vd7qlwtn',
#       'question_type': 'text'},
#      {'label': 'X (Twitter) handle',
#       'answer': 'https://x.com/you425you',
#       'question_id': 'j7ohhsuw',
#       'question_type': 'text'},
#      {'label': 'Who invited you?',
#       'answer': 'BZB',
#       'question_id': 'hs5j82g7',
#       'question_type': 'text'}],
#     'solana_address': None,
#     'user_api_id': 'usr-uD2qAz2jK1umrTn',
#     'user_name': 'you425',
#     'user_email': 'youdietagao@gmail.com',
#     'user_first_name': 'you',
#     'user_last_name': '425',
#     'name': 'you425',
#     'email': 'youdietagao@gmail.com',
#     'checked_in_at': None,
#     'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-DZyvQ9EoqohbNFq',
#     'event_tickets': [{'amount': 0,
#       'amount_discount': 0,
#       'amount_tax': 0,
#       'api_id': 'eventticket-g2Eqc8myxUdugta',
#       'checked_in_at': None,
#       'currency': 'usd',
#       'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#       'is_captured': False,
#       'name': 'VIP'}],
#     'event_ticket': {'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-g2Eqc8myxUdugta',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}}},
#   {'api_id': 'gst-6P9EYWHwFqvxOE7',
#    'guest': {'api_id': 'gst-6P9EYWHwFqvxOE7',
#     'approval_status': 'approved',
#     'created_at': '2025-06-04T04:44:26.897Z',
#     'custom_source': None,
#     'eth_address': None,
#     'invited_at': None,
#     'joined_at': None,
#     'phone_number': None,
#     'registered_at': '2025-06-04T04:44:26.897Z',
#     'registration_answers': [{'label': 'Name or Alias',
#       'answer': '灯篭',
#       'question_id': 'pg6lhrro',
#       'question_type': 'text'},
#      {'label': 'Area of activity in Web3',
#       'answer': 'Community / Marketing / Investment...etc',
#       'question_id': 'jlm8db1x',
#       'question_type': 'text'},
#      {'label': 'Telegram handle',
#       'answer': '@Tourou',
#       'question_id': 'vd7qlwtn',
#       'question_type': 'text'},
#      {'label': 'X (Twitter) handle',
#       'answer': '@TourouJPN',
#       'question_id': 'j7ohhsuw',
#       'question_type': 'text'},
#      {'label': 'Who invited you?',
#       'answer': 'BZB',
#       'question_id': 'hs5j82g7',
#       'question_type': 'text'}],
#     'solana_address': None,
#     'user_api_id': 'usr-Z3bXzK37E3MuLwX',
#     'user_name': 'Tourou',
#     'user_email': 'touroujpn@gmail.com',
#     'user_first_name': 'Tourou',
#     'user_last_name': '灯篭',
#     'name': 'Tourou',
#     'email': 'touroujpn@gmail.com',
#     'checked_in_at': None,
#     'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-R6IhkvNtPX9eDJT',
#     'event_tickets': [{'amount': 0,
#       'amount_discount': 0,
#       'amount_tax': 0,
#       'api_id': 'eventticket-koKWVDCOULunPqt',
#       'checked_in_at': None,
#       'currency': 'usd',
#       'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#       'is_captured': False,
#       'name': 'VIP'}],
#     'event_ticket': {'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-koKWVDCOULunPqt',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}}},
#   {'api_id': 'gst-HHwHbWkop2SCuE2',
#    'guest': {'api_id': 'gst-HHwHbWkop2SCuE2',
#     'approval_status': 'approved',
#     'created_at': '2025-06-04T05:12:58.184Z',
#     'custom_source': None,
#     'eth_address': None,
#     'invited_at': None,
#     'joined_at': None,
#     'phone_number': None,
#     'registered_at': '2025-06-04T05:12:58.183Z',
#     'registration_answers': [{'label': 'Name or Alias',
#       'answer': 'Gumi-chan',
#       'question_id': 'pg6lhrro',
#       'question_type': 'text'},
#      {'label': 'Area of activity in Web3',
#       'answer': 'NFT',
#       'question_id': 'jlm8db1x',
#       'question_type': 'text'},
#      {'label': 'Telegram handle',
#       'answer': 'miosan_gumichan',
#       'question_id': 'vd7qlwtn',
#       'question_type': 'text'},
#      {'label': 'X (Twitter) handle',
#       'answer': 'Kawaiigirl_en',
#       'question_id': 'j7ohhsuw',
#       'question_type': 'text'},
#      {'label': 'Who invited you?',
#       'answer': 'BZB',
#       'question_id': 'hs5j82g7',
#       'question_type': 'text'}],
#     'solana_address': None,
#     'user_api_id': 'usr-b0eXevuVSFUgusW',
#     'user_name': 'Mio Yonenaga',
#     'user_email': 'mio.yonenaga@sbinft.co.jp',
#     'user_first_name': 'Mio',
#     'user_last_name': 'Yonenaga',
#     'name': 'Mio Yonenaga',
#     'email': 'mio.yonenaga@sbinft.co.jp',
#     'checked_in_at': None,
#     'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-ZyEznKt7FE1BctD',
#     'event_tickets': [{'amount': 0,
#       'amount_discount': 0,
#       'amount_tax': 0,
#       'api_id': 'eventticket-jWlC0HuGJEd8PHR',
#       'checked_in_at': None,
#       'currency': 'usd',
#       'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#       'is_captured': False,
#       'name': 'VIP'}],
#     'event_ticket': {'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-jWlC0HuGJEd8PHR',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}}},
#   {'api_id': 'gst-yqwz8fPhtOsQrof',
#    'guest': {'api_id': 'gst-yqwz8fPhtOsQrof',
#     'approval_status': 'approved',
#     'created_at': '2025-06-04T05:46:01.274Z',
#     'custom_source': None,
#     'eth_address': None,
#     'invited_at': None,
#     'joined_at': None,
#     'phone_number': None,
#     'registered_at': '2025-06-04T05:46:01.273Z',
#     'registration_answers': [{'label': 'Name or Alias',
#       'answer': 'AMEYUMI',
#       'question_id': 'pg6lhrro',
#       'question_type': 'text'},
#      {'label': 'Area of activity in Web3',
#       'answer': 'NFT',
#       'question_id': 'jlm8db1x',
#       'question_type': 'text'},
#      {'label': 'Telegram handle',
#       'answer': 'xxurainbow',
#       'question_id': 'vd7qlwtn',
#       'question_type': 'text'},
#      {'label': 'X (Twitter) handle',
#       'answer': 'https://x.com/rain_vc',
#       'question_id': 'j7ohhsuw',
#       'question_type': 'text'},
#      {'label': 'Who invited you?',
#       'answer': 'BZB',
#       'question_id': 'hs5j82g7',
#       'question_type': 'text'}],
#     'solana_address': None,
#     'user_api_id': 'usr-KzxEYUED27Iwf4A',
#     'user_name': 'AMEYUMI',
#     'user_email': 'ameyumicash@gmail.com',
#     'user_first_name': '弘司',
#     'user_last_name': '北原',
#     'name': 'AMEYUMI',
#     'email': 'ameyumicash@gmail.com',
#     'checked_in_at': None,
#     'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-BgLgT8hLNhj9c0O',
#     'event_tickets': [{'amount': 0,
#       'amount_discount': 0,
#       'amount_tax': 0,
#       'api_id': 'eventticket-7eKFNN10ne1T7ZH',
#       'checked_in_at': None,
#       'currency': 'usd',
#       'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#       'is_captured': False,
#       'name': 'VIP'}],
#     'event_ticket': {'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-7eKFNN10ne1T7ZH',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}}},
#   {'api_id': 'gst-FVosfgYGoR01LM8',
#    'guest': {'api_id': 'gst-FVosfgYGoR01LM8',
#     'approval_status': 'approved',
#     'created_at': '2025-06-04T09:19:14.934Z',
#     'custom_source': None,
#     'eth_address': None,
#     'invited_at': None,
#     'joined_at': None,
#     'phone_number': None,
#     'registered_at': '2025-06-04T09:19:14.934Z',
#     'registration_answers': [{'label': 'Name or Alias',
#       'answer': 'くし/Crypto文鳥',
#       'question_id': 'pg6lhrro',
#       'question_type': 'text'},
#      {'label': 'Area of activity in Web3',
#       'answer': '仮想通貨取引所',
#       'question_id': 'jlm8db1x',
#       'question_type': 'text'},
#      {'label': 'Telegram handle',
#       'answer': '@kusi_nft',
#       'question_id': 'vd7qlwtn',
#       'question_type': 'text'},
#      {'label': 'X (Twitter) handle',
#       'answer': 'https://x.com/nft_kusi',
#       'question_id': 'j7ohhsuw',
#       'question_type': 'text'},
#      {'label': 'Who invited you?',
#       'answer': '@Ari_creditscend',
#       'question_id': 'hs5j82g7',
#       'question_type': 'text'}],
#     'solana_address': None,
#     'user_api_id': 'usr-BFBmECgIBqyxPe6',
#     'user_name': 'kusi',
#     'user_email': 'kusi18fosu@gmail.com',
#     'user_first_name': 'Kusi',
#     'user_last_name': '',
#     'name': 'kusi',
#     'email': 'kusi18fosu@gmail.com',
#     'checked_in_at': None,
#     'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-pO3voP81Yo5iQLO',
#     'event_tickets': [{'amount': 0,
#       'amount_discount': 0,
#       'amount_tax': 0,
#       'api_id': 'eventticket-r5Dc3feIgsh08e9',
#       'checked_in_at': None,
#       'currency': 'usd',
#       'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#       'is_captured': False,
#       'name': 'VIP'}],
#     'event_ticket': {'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-r5Dc3feIgsh08e9',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}}},
#   {'api_id': 'gst-QxnFbngkrSrVgsf',
#    'guest': {'api_id': 'gst-QxnFbngkrSrVgsf',
#     'approval_status': 'approved',
#     'created_at': '2025-06-04T11:21:04.477Z',
#     'custom_source': None,
#     'eth_address': None,
#     'invited_at': None,
#     'joined_at': None,
#     'phone_number': None,
#     'registered_at': '2025-06-04T11:21:04.476Z',
#     'registration_answers': [{'label': 'Name or Alias',
#       'answer': 'Tarako',
#       'question_id': 'pg6lhrro',
#       'question_type': 'text'},
#      {'label': 'Area of activity in Web3',
#       'answer': 'Token',
#       'question_id': 'jlm8db1x',
#       'question_type': 'text'},
#      {'label': 'Telegram handle',
#       'answer': '@nftarako',
#       'question_id': 'vd7qlwtn',
#       'question_type': 'text'},
#      {'label': 'X (Twitter) handle',
#       'answer': 'https://x.com/NFT_Tarako',
#       'question_id': 'j7ohhsuw',
#       'question_type': 'text'},
#      {'label': 'Who invited you?',
#       'answer': 'BZB',
#       'question_id': 'hs5j82g7',
#       'question_type': 'text'}],
#     'solana_address': None,
#     'user_api_id': 'usr-QQpAjq1U5waEDzC',
#     'user_name': '非代替性たらこ',
#     'user_email': 'nftarako@gmail.com',
#     'user_first_name': None,
#     'user_last_name': None,
#     'name': '非代替性たらこ',
#     'email': 'nftarako@gmail.com',
#     'checked_in_at': None,
#     'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-bXIFp9u2GS7H9BE',
#     'event_tickets': [{'amount': 0,
#       'amount_discount': 0,
#       'amount_tax': 0,
#       'api_id': 'eventticket-Jn1J6yTklkaGlim',
#       'checked_in_at': None,
#       'currency': 'usd',
#       'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#       'is_captured': False,
#       'name': 'VIP'}],
#     'event_ticket': {'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-Jn1J6yTklkaGlim',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}}},
#   {'api_id': 'gst-qnfFwGO6t0cCJBY',
#    'guest': {'api_id': 'gst-qnfFwGO6t0cCJBY',
#     'approval_status': 'approved',
#     'created_at': '2025-06-04T11:31:05.856Z',
#     'custom_source': None,
#     'eth_address': None,
#     'invited_at': None,
#     'joined_at': None,
#     'phone_number': None,
#     'registered_at': '2025-06-04T11:31:05.856Z',
#     'registration_answers': [{'label': 'Name or Alias',
#       'answer': 'Pancami',
#       'question_id': 'pg6lhrro',
#       'question_type': 'text'},
#      {'label': 'Area of activity in Web3',
#       'answer': 'Japan',
#       'question_id': 'jlm8db1x',
#       'question_type': 'text'},
#      {'label': 'Telegram handle',
#       'answer': '@pancake_crypto0',
#       'question_id': 'vd7qlwtn',
#       'question_type': 'text'},
#      {'label': 'X (Twitter) handle',
#       'answer': '@pancake_crypto0',
#       'question_id': 'j7ohhsuw',
#       'question_type': 'text'},
#      {'label': 'Who invited you?',
#       'answer': 'Ari',
#       'question_id': 'hs5j82g7',
#       'question_type': 'text'}],
#     'solana_address': None,
#     'user_api_id': 'usr-zvGlgt5OZzjVnk5',
#     'user_name': 'Pancami',
#     'user_email': 'rerere_no_ren321@yahoo.co.jp',
#     'user_first_name': 'Pancami',
#     'user_last_name': '',
#     'name': 'Pancami',
#     'email': 'rerere_no_ren321@yahoo.co.jp',
#     'checked_in_at': None,
#     'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-57BarN9wbovToEh',
#     'event_tickets': [{'amount': 0,
#       'amount_discount': 0,
#       'amount_tax': 0,
#       'api_id': 'eventticket-CkPLHjf4f5GzLDQ',
#       'checked_in_at': None,
#       'currency': 'usd',
#       'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#       'is_captured': False,
#       'name': 'VIP'}],
#     'event_ticket': {'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-CkPLHjf4f5GzLDQ',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}}},
#   {'api_id': 'gst-CpqyBigk1ERpGmY',
#    'guest': {'api_id': 'gst-CpqyBigk1ERpGmY',
#     'approval_status': 'approved',
#     'created_at': '2025-06-05T02:40:30.142Z',
#     'custom_source': None,
#     'eth_address': None,
#     'invited_at': None,
#     'joined_at': None,
#     'phone_number': None,
#     'registered_at': '2025-06-05T02:40:30.142Z',
#     'registration_answers': [{'label': 'Name or Alias',
#       'answer': '大石',
#       'question_id': 'pg6lhrro',
#       'question_type': 'text'},
#      {'label': 'Area of activity in Web3',
#       'answer': 'X',
#       'question_id': 'jlm8db1x',
#       'question_type': 'text'},
#      {'label': 'Telegram handle',
#       'answer': '@udonkue',
#       'question_id': 'vd7qlwtn',
#       'question_type': 'text'},
#      {'label': 'X (Twitter) handle',
#       'answer': 'https://x.com/saamon2500',
#       'question_id': 'j7ohhsuw',
#       'question_type': 'text'},
#      {'label': 'Who invited you?',
#       'answer': 'ふにまん',
#       'question_id': 'hs5j82g7',
#       'question_type': 'text'}],
#     'solana_address': None,
#     'user_api_id': 'usr-Y6uTTjgPky0ypBP',
#     'user_name': 'サーモン',
#     'user_email': 'saamon1986@gmail.com',
#     'user_first_name': None,
#     'user_last_name': None,
#     'name': 'サーモン',
#     'email': 'saamon1986@gmail.com',
#     'checked_in_at': None,
#     'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-WoHusBrd9mlJk15',
#     'event_tickets': [{'amount': 0,
#       'amount_discount': 0,
#       'amount_tax': 0,
#       'api_id': 'eventticket-Gv1ayMR1D9ppEWU',
#       'checked_in_at': None,
#       'currency': 'usd',
#       'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#       'is_captured': False,
#       'name': 'VIP'}],
#     'event_ticket': {'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-Gv1ayMR1D9ppEWU',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}}},
#   {'api_id': 'gst-eTXDIqmzXxSK7Vu',
#    'guest': {'api_id': 'gst-eTXDIqmzXxSK7Vu',
#     'approval_status': 'approved',
#     'created_at': '2025-06-05T04:58:34.175Z',
#     'custom_source': None,
#     'eth_address': None,
#     'invited_at': None,
#     'joined_at': None,
#     'phone_number': None,
#     'registered_at': '2025-06-05T04:58:34.175Z',
#     'registration_answers': [{'label': 'Name or Alias',
#       'answer': '@web3_honey',
#       'question_id': 'pg6lhrro',
#       'question_type': 'text'},
#      {'label': 'Area of activity in Web3',
#       'answer': 'all',
#       'question_id': 'jlm8db1x',
#       'question_type': 'text'},
#      {'label': 'Telegram handle',
#       'answer': '@web3_honey',
#       'question_id': 'vd7qlwtn',
#       'question_type': 'text'},
#      {'label': 'X (Twitter) handle',
#       'answer': 'https://x.com/web3_honey',
#       'question_id': 'j7ohhsuw',
#       'question_type': 'text'},
#      {'label': 'Who invited you?',
#       'answer': 'BZB',
#       'question_id': 'hs5j82g7',
#       'question_type': 'text'}],
#     'solana_address': None,
#     'user_api_id': 'usr-wG9rqzWLwONRWDe',
#     'user_name': 'web3honey',
#     'user_email': 'web3honey@buzzbridge.capital',
#     'user_first_name': 'honey',
#     'user_last_name': 'web3',
#     'name': 'web3honey',
#     'email': 'web3honey@buzzbridge.capital',
#     'checked_in_at': None,
#     'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-0TVLQA50dg0FnvA',
#     'event_tickets': [{'amount': 0,
#       'amount_discount': 0,
#       'amount_tax': 0,
#       'api_id': 'eventticket-eBMi8aujOQbP6z5',
#       'checked_in_at': None,
#       'currency': 'usd',
#       'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#       'is_captured': False,
#       'name': 'VIP'}],
#     'event_ticket': {'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-eBMi8aujOQbP6z5',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}}},
#   {'api_id': 'gst-Q1xdehUTZ0Xlfu1',
#    'guest': {'api_id': 'gst-Q1xdehUTZ0Xlfu1',
#     'approval_status': 'approved',
#     'created_at': '2025-06-05T04:58:38.868Z',
#     'custom_source': None,
#     'eth_address': None,
#     'invited_at': None,
#     'joined_at': None,
#     'phone_number': None,
#     'registered_at': '2025-06-05T04:58:38.868Z',
#     'registration_answers': [{'label': 'Name or Alias',
#       'answer': 'hunisan',
#       'question_id': 'pg6lhrro',
#       'question_type': 'text'},
#      {'label': 'Area of activity in Web3',
#       'answer': 'all',
#       'question_id': 'jlm8db1x',
#       'question_type': 'text'},
#      {'label': 'Telegram handle',
#       'answer': 'hunisan',
#       'question_id': 'vd7qlwtn',
#       'question_type': 'text'},
#      {'label': 'X (Twitter) handle',
#       'answer': 'https://x.com/huni_crypto',
#       'question_id': 'j7ohhsuw',
#       'question_type': 'text'},
#      {'label': 'Who invited you?',
#       'answer': 'BZB',
#       'question_id': 'hs5j82g7',
#       'question_type': 'text'}],
#     'solana_address': None,
#     'user_api_id': 'usr-zqyf32Z6JeAroDq',
#     'user_name': 'hunisan',
#     'user_email': 'noboruh@buzzbridge.capital',
#     'user_first_name': 'Hunisan',
#     'user_last_name': 'Hirayama',
#     'name': 'hunisan',
#     'email': 'noboruh@buzzbridge.capital',
#     'checked_in_at': None,
#     'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-tUyEePB0NIXKAfR',
#     'event_tickets': [{'amount': 0,
#       'amount_discount': 0,
#       'amount_tax': 0,
#       'api_id': 'eventticket-4HsAk8035MCuLKx',
#       'checked_in_at': None,
#       'currency': 'usd',
#       'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#       'is_captured': False,
#       'name': 'VIP'}],
#     'event_ticket': {'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-4HsAk8035MCuLKx',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}}},
#   {'api_id': 'gst-d9ZqcbYchSlLrzh',
#    'guest': {'api_id': 'gst-d9ZqcbYchSlLrzh',
#     'approval_status': 'approved',
#     'created_at': '2025-06-05T05:01:41.229Z',
#     'custom_source': None,
#     'eth_address': None,
#     'invited_at': None,
#     'joined_at': None,
#     'phone_number': None,
#     'registered_at': '2025-06-05T05:01:41.228Z',
#     'registration_answers': [{'label': 'Name or Alias',
#       'answer': 'Aki ',
#       'question_id': 'pg6lhrro',
#       'question_type': 'text'},
#      {'label': 'Area of activity in Web3',
#       'answer': 'game',
#       'question_id': 'jlm8db1x',
#       'question_type': 'text'},
#      {'label': 'Telegram handle',
#       'answer': 'Aki_BCG',
#       'question_id': 'vd7qlwtn',
#       'question_type': 'text'},
#      {'label': 'X (Twitter) handle',
#       'answer': 'aki_playaxie',
#       'question_id': 'j7ohhsuw',
#       'question_type': 'text'},
#      {'label': 'Who invited you?',
#       'answer': 'BZB',
#       'question_id': 'hs5j82g7',
#       'question_type': 'text'}],
#     'solana_address': None,
#     'user_api_id': 'usr-BvCCLdjFH8U8gIC',
#     'user_name': 'Aki',
#     'user_email': 'chiaki.goto.kame@gmail.com',
#     'user_first_name': 'Aki',
#     'user_last_name': '',
#     'name': 'Aki',
#     'email': 'chiaki.goto.kame@gmail.com',
#     'checked_in_at': None,
#     'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-M4VB2STvi9kSQjZ',
#     'event_tickets': [{'amount': 0,
#       'amount_discount': 0,
#       'amount_tax': 0,
#       'api_id': 'eventticket-RemIre5XioHoqTs',
#       'checked_in_at': None,
#       'currency': 'usd',
#       'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#       'is_captured': False,
#       'name': 'VIP'}],
#     'event_ticket': {'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-RemIre5XioHoqTs',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}}},
#   {'api_id': 'gst-bGmpnyQkkR2KMMF',
#    'guest': {'api_id': 'gst-bGmpnyQkkR2KMMF',
#     'approval_status': 'approved',
#     'created_at': '2025-06-05T06:32:03.199Z',
#     'custom_source': None,
#     'eth_address': None,
#     'invited_at': None,
#     'joined_at': None,
#     'phone_number': None,
#     'registered_at': '2025-06-05T06:32:03.199Z',
#     'registration_answers': [{'label': 'Name or Alias',
#       'answer': 'Yamasho',
#       'question_id': 'pg6lhrro',
#       'question_type': 'text'},
#      {'label': 'Area of activity in Web3',
#       'answer': 'Web3 Adviser',
#       'question_id': 'jlm8db1x',
#       'question_type': 'text'},
#      {'label': 'Telegram handle',
#       'answer': 'Wink_Three_Yamasho',
#       'question_id': 'vd7qlwtn',
#       'question_type': 'text'},
#      {'label': 'X (Twitter) handle',
#       'answer': 'https://x.com/Yamasho_rivique',
#       'question_id': 'j7ohhsuw',
#       'question_type': 'text'},
#      {'label': 'Who invited you?',
#       'answer': 'BZB',
#       'question_id': 'hs5j82g7',
#       'question_type': 'text'}],
#     'solana_address': None,
#     'user_api_id': 'usr-LCt7o3XoAvewcsV',
#     'user_name': 'Yamasho',
#     'user_email': 'yamasho.wink3@gmail.com',
#     'user_first_name': 'Yamasho',
#     'user_last_name': '',
#     'name': 'Yamasho',
#     'email': 'yamasho.wink3@gmail.com',
#     'checked_in_at': None,
#     'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-mnB1zfSR0qp9Cg5',
#     'event_tickets': [{'amount': 0,
#       'amount_discount': 0,
#       'amount_tax': 0,
#       'api_id': 'eventticket-X8gs6JJBhHFG3BL',
#       'checked_in_at': None,
#       'currency': 'usd',
#       'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#       'is_captured': False,
#       'name': 'VIP'}],
#     'event_ticket': {'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-X8gs6JJBhHFG3BL',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}}},
#   {'api_id': 'gst-UfdXMEWanVxGgBl',
#    'guest': {'api_id': 'gst-UfdXMEWanVxGgBl',
#     'approval_status': 'approved',
#     'created_at': '2025-06-05T10:04:00.170Z',
#     'custom_source': None,
#     'eth_address': None,
#     'invited_at': None,
#     'joined_at': None,
#     'phone_number': None,
#     'registered_at': '2025-06-05T10:04:00.169Z',
#     'registration_answers': [{'label': 'Name or Alias',
#       'answer': 'JP',
#       'question_id': 'pg6lhrro',
#       'question_type': 'text'},
#      {'label': 'Area of activity in Web3',
#       'answer': 'Marketing lead',
#       'question_id': 'jlm8db1x',
#       'question_type': 'text'},
#      {'label': 'Telegram handle',
#       'answer': '@JPIPX',
#       'question_id': 'vd7qlwtn',
#       'question_type': 'text'},
#      {'label': 'X (Twitter) handle',
#       'answer': '@JP_IPX',
#       'question_id': 'j7ohhsuw',
#       'question_type': 'text'},
#      {'label': 'Who invited you?',
#       'answer': 'https://www.linkedin.com/in/ryan-yousang-chin-59598687',
#       'question_id': 'hs5j82g7',
#       'question_type': 'text'}],
#     'solana_address': None,
#     'user_api_id': 'usr-x1R4yL968EVvWpz',
#     'user_name': 'JP',
#     'user_email': 'junpyo.ipx@gmail.com',
#     'user_first_name': 'Junpyo',
#     'user_last_name': 'Lee',
#     'name': 'JP',
#     'email': 'junpyo.ipx@gmail.com',
#     'checked_in_at': None,
#     'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-DmqLgKVgPmnZCeh',
#     'event_tickets': [{'amount': 0,
#       'amount_discount': 0,
#       'amount_tax': 0,
#       'api_id': 'eventticket-4ZCEXwWBlDMQFMG',
#       'checked_in_at': None,
#       'currency': 'usd',
#       'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#       'is_captured': False,
#       'name': 'VIP'}],
#     'event_ticket': {'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-4ZCEXwWBlDMQFMG',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
# ...
#    'guest': {'api_id': 'gst-05gRxZ2ED4wlWA7',
#     'approval_status': 'approved',
#     'created_at': '2025-06-08T21:37:42.562Z',
#     'custom_source': None,
#     'eth_address': None,
#     'invited_at': None,
#     'joined_at': None,
#     'phone_number': None,
#     'registered_at': '2025-06-08T21:37:42.561Z',
#     'registration_answers': [{'label': 'Name or Alias',
#       'answer': 'Yuuuuu',
#       'question_id': 'pg6lhrro',
#       'question_type': 'text'},
#      {'label': 'Area of activity in Web3',
#       'answer': 'Game',
#       'question_id': 'jlm8db1x',
#       'question_type': 'text'},
#      {'label': 'Telegram handle',
#       'answer': 'yuu_axielabs',
#       'question_id': 'vd7qlwtn',
#       'question_type': 'text'},
#      {'label': 'X (Twitter) handle',
#       'answer': 'https://x.com/yuu_AxieLabs',
#       'question_id': 'j7ohhsuw',
#       'question_type': 'text'},
#      {'label': 'Who invited you?',
#       'answer': 'Amechan',
#       'question_id': 'hs5j82g7',
#       'question_type': 'text'}],
#     'solana_address': None,
#     'user_api_id': 'usr-8tpdtXtVBCgSth3',
#     'user_name': 'YUUUUU',
#     'user_email': 'yuuuuu@zthreee.net',
#     'user_first_name': 'Yuuuuu',
#     'user_last_name': '',
#     'name': 'YUUUUU',
#     'email': 'yuuuuu@zthreee.net',
#     'checked_in_at': None,
#     'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-pmxCg8xE4DA8NWM',
#     'event_tickets': [{'amount': 0,
#       'amount_discount': 0,
#       'amount_tax': 0,
#       'api_id': 'eventticket-F2BmBga9k5OSvSC',
#       'checked_in_at': None,
#       'currency': 'usd',
#       'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#       'is_captured': False,
#       'name': 'VIP'}],
#     'event_ticket': {'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-F2BmBga9k5OSvSC',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}}},
#   {'api_id': 'gst-YGsfgvEQe4A8vC3',
#    'guest': {'api_id': 'gst-YGsfgvEQe4A8vC3',
#     'approval_status': 'approved',
#     'created_at': '2025-06-08T23:44:05.382Z',
#     'custom_source': None,
#     'eth_address': None,
#     'invited_at': None,
#     'joined_at': None,
#     'phone_number': None,
#     'registered_at': '2025-06-08T23:44:05.382Z',
#     'registration_answers': [{'label': 'Name or Alias',
#       'answer': 'DeFitterジョン',
#       'question_id': 'pg6lhrro',
#       'question_type': 'text'},
#      {'label': 'Area of activity in Web3',
#       'answer': 'BCG/GameFi',
#       'question_id': 'jlm8db1x',
#       'question_type': 'text'},
#      {'label': 'Telegram handle',
#       'answer': 'https://t.me/manman197385',
#       'question_id': 'vd7qlwtn',
#       'question_type': 'text'},
#      {'label': 'X (Twitter) handle',
#       'answer': '@fitter_de',
#       'question_id': 'j7ohhsuw',
#       'question_type': 'text'},
#      {'label': 'Who invited you?',
#       'answer': 'tanukichi',
#       'question_id': 'hs5j82g7',
#       'question_type': 'text'}],
#     'solana_address': None,
#     'user_api_id': 'usr-kvWm1SfWbRL0Ccn',
#     'user_name': 'Defitterジョン',
#     'user_email': 'john@blockchaingame.co.jp',
#     'user_first_name': 'ジョン',
#     'user_last_name': 'Defitter',
#     'name': 'Defitterジョン',
#     'email': 'john@blockchaingame.co.jp',
#     'checked_in_at': None,
#     'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-8AjpMVBpdGKkKeB',
#     'event_tickets': [{'amount': 0,
#       'amount_discount': 0,
#       'amount_tax': 0,
#       'api_id': 'eventticket-XR9pNLmCl3vdAmd',
#       'checked_in_at': None,
#       'currency': 'usd',
#       'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#       'is_captured': False,
#       'name': 'VIP'}],
#     'event_ticket': {'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-XR9pNLmCl3vdAmd',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}}},
#   {'api_id': 'gst-WfEpG73L7w29rWU',
#    'guest': {'api_id': 'gst-WfEpG73L7w29rWU',
#     'approval_status': 'approved',
#     'created_at': '2025-06-09T05:21:37.873Z',
#     'custom_source': None,
#     'eth_address': None,
#     'invited_at': None,
#     'joined_at': None,
#     'phone_number': None,
#     'registered_at': '2025-06-09T05:21:37.872Z',
#     'registration_answers': [{'label': 'Name or Alias',
#       'answer': 'noma',
#       'question_id': 'pg6lhrro',
#       'question_type': 'text'},
#      {'label': 'Area of activity in Web3',
#       'answer': 'BCG',
#       'question_id': 'jlm8db1x',
#       'question_type': 'text'},
#      {'label': 'Telegram handle',
#       'answer': 'n0ma_nn',
#       'question_id': 'vd7qlwtn',
#       'question_type': 'text'},
#      {'label': 'X (Twitter) handle',
#       'answer': '_n0ma',
#       'question_id': 'j7ohhsuw',
#       'question_type': 'text'},
#      {'label': 'Who invited you?',
#       'answer': 'BZB',
#       'question_id': 'hs5j82g7',
#       'question_type': 'text'}],
#     'solana_address': None,
#     'user_api_id': 'usr-p6m4uZn0kqe5mFU',
#     'user_name': 'noma',
#     'user_email': 'noma.zenz00@gmail.com',
#     'user_first_name': 'Noma',
#     'user_last_name': '',
#     'name': 'noma',
#     'email': 'noma.zenz00@gmail.com',
#     'checked_in_at': None,
#     'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-HDpsjNg4FNZqpYw',
#     'event_tickets': [{'amount': 0,
#       'amount_discount': 0,
#       'amount_tax': 0,
#       'api_id': 'eventticket-cuxR39wG2a7aWnQ',
#       'checked_in_at': None,
#       'currency': 'usd',
#       'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#       'is_captured': False,
#       'name': 'VIP'}],
#     'event_ticket': {'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-cuxR39wG2a7aWnQ',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}}},
#   {'api_id': 'gst-nYzS07z4KpBE2Z3',
#    'guest': {'api_id': 'gst-nYzS07z4KpBE2Z3',
#     'approval_status': 'approved',
#     'created_at': '2025-06-09T07:15:26.100Z',
#     'custom_source': None,
#     'eth_address': None,
#     'invited_at': None,
#     'joined_at': None,
#     'phone_number': None,
#     'registered_at': '2025-06-09T07:15:26.099Z',
#     'registration_answers': [{'label': 'Name or Alias',
#       'answer': 'zoku',
#       'question_id': 'pg6lhrro',
#       'question_type': 'text'},
#      {'label': 'Area of activity in Web3',
#       'answer': 'BCG User',
#       'question_id': 'jlm8db1x',
#       'question_type': 'text'},
#      {'label': 'Telegram handle',
#       'answer': 'zoku_chandayo',
#       'question_id': 'vd7qlwtn',
#       'question_type': 'text'},
#      {'label': 'X (Twitter) handle',
#       'answer': 'elf_yamasters',
#       'question_id': 'j7ohhsuw',
#       'question_type': 'text'},
#      {'label': 'Who invited you?',
#       'answer': 'BZB',
#       'question_id': 'hs5j82g7',
#       'question_type': 'text'}],
#     'solana_address': None,
#     'user_api_id': 'usr-3yuqYo2suOm0WDV',
#     'user_name': 'ぞく',
#     'user_email': 'yamaryou112@gmail.com',
#     'user_first_name': '',
#     'user_last_name': '',
#     'name': 'ぞく',
#     'email': 'yamaryou112@gmail.com',
#     'checked_in_at': None,
#     'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-ucQu1bDEAc1Ys4F',
#     'event_tickets': [{'amount': 0,
#       'amount_discount': 0,
#       'amount_tax': 0,
#       'api_id': 'eventticket-FdvBMBfFLwBwDQL',
#       'checked_in_at': None,
#       'currency': 'usd',
#       'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#       'is_captured': False,
#       'name': 'VIP'}],
#     'event_ticket': {'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-FdvBMBfFLwBwDQL',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}}},
#   {'api_id': 'gst-Csm9M5cCBRW4W4B',
#    'guest': {'api_id': 'gst-Csm9M5cCBRW4W4B',
#     'approval_status': 'approved',
#     'created_at': '2025-06-09T07:29:33.595Z',
#     'custom_source': None,
#     'eth_address': None,
#     'invited_at': None,
#     'joined_at': None,
#     'phone_number': None,
#     'registered_at': '2025-06-09T07:29:33.595Z',
#     'registration_answers': [{'label': 'Name or Alias',
#       'answer': 'goose',
#       'question_id': 'pg6lhrro',
#       'question_type': 'text'},
#      {'label': 'Area of activity in Web3',
#       'answer': 'BCG and DeFi',
#       'question_id': 'jlm8db1x',
#       'question_type': 'text'},
#      {'label': 'Telegram handle',
#       'answer': 'teikokubank',
#       'question_id': 'vd7qlwtn',
#       'question_type': 'text'},
#      {'label': 'X (Twitter) handle',
#       'answer': 'teikokubank',
#       'question_id': 'j7ohhsuw',
#       'question_type': 'text'},
#      {'label': 'Who invited you?',
#       'answer': 'BZB',
#       'question_id': 'hs5j82g7',
#       'question_type': 'text'}],
#     'solana_address': None,
#     'user_api_id': 'usr-MOSmsJOprBg4eS9',
#     'user_name': 'goose',
#     'user_email': 'imperialgooose@gmail.com',
#     'user_first_name': None,
#     'user_last_name': None,
#     'name': 'goose',
#     'email': 'imperialgooose@gmail.com',
#     'checked_in_at': None,
#     'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-YChCZ2UFUgqgvkk',
#     'event_tickets': [{'amount': 0,
#       'amount_discount': 0,
#       'amount_tax': 0,
#       'api_id': 'eventticket-p0JLDjH8Zq1y2iv',
#       'checked_in_at': None,
#       'currency': 'usd',
#       'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#       'is_captured': False,
#       'name': 'VIP'}],
#     'event_ticket': {'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-p0JLDjH8Zq1y2iv',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}}},
#   {'api_id': 'gst-E87bdL3SB2wyBY0',
#    'guest': {'api_id': 'gst-E87bdL3SB2wyBY0',
#     'approval_status': 'approved',
#     'created_at': '2025-06-09T10:00:31.679Z',
#     'custom_source': None,
#     'eth_address': None,
#     'invited_at': None,
#     'joined_at': None,
#     'phone_number': None,
#     'registered_at': '2025-06-09T10:00:31.679Z',
#     'registration_answers': [{'label': 'Name or Alias',
#       'answer': 'Yano Taiga',
#       'question_id': 'pg6lhrro',
#       'question_type': 'text'},
#      {'label': 'Area of activity in Web3',
#       'answer': 'Marketplace and Crypto exchange',
#       'question_id': 'jlm8db1x',
#       'question_type': 'text'},
#      {'label': 'Telegram handle',
#       'answer': '@taigamercari',
#       'question_id': 'vd7qlwtn',
#       'question_type': 'text'},
#      {'label': 'X (Twitter) handle',
#       'answer': 'https://x.com/NFT_taiga',
#       'question_id': 'j7ohhsuw',
#       'question_type': 'text'},
#      {'label': 'Who invited you?',
#       'answer': 'BZB',
#       'question_id': 'hs5j82g7',
#       'question_type': 'text'}],
#     'solana_address': None,
#     'user_api_id': 'usr-P1rCnjP3tXYQo9o',
#     'user_name': 'Yano Taiga',
#     'user_email': 'taigayano1@gmail.com',
#     'user_first_name': 'Yano',
#     'user_last_name': 'Taiga',
#     'name': 'Yano Taiga',
#     'email': 'taigayano1@gmail.com',
#     'checked_in_at': None,
#     'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-PryRJSASFWjbfDO',
#     'event_tickets': [{'amount': 0,
#       'amount_discount': 0,
#       'amount_tax': 0,
#       'api_id': 'eventticket-uM1Xo2HMAG73J8Z',
#       'checked_in_at': None,
#       'currency': 'usd',
#       'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#       'is_captured': False,
#       'name': 'VIP'}],
#     'event_ticket': {'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-uM1Xo2HMAG73J8Z',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}}},
#   {'api_id': 'gst-ZLXc1obs0Rp6L2X',
#    'guest': {'api_id': 'gst-ZLXc1obs0Rp6L2X',
#     'approval_status': 'approved',
#     'created_at': '2025-06-09T11:29:51.069Z',
#     'custom_source': None,
#     'eth_address': None,
#     'invited_at': None,
#     'joined_at': None,
#     'phone_number': None,
#     'registered_at': '2025-06-09T11:29:51.069Z',
#     'registration_answers': [{'label': 'Name or Alias',
#       'answer': 'Tomoya',
#       'question_id': 'pg6lhrro',
#       'question_type': 'text'},
#      {'label': 'Area of activity in Web3',
#       'answer': 'BCG',
#       'question_id': 'jlm8db1x',
#       'question_type': 'text'},
#      {'label': 'Telegram handle',
#       'answer': '@tomoya1109',
#       'question_id': 'vd7qlwtn',
#       'question_type': 'text'},
#      {'label': 'X (Twitter) handle',
#       'answer': '@tomoya_11109',
#       'question_id': 'j7ohhsuw',
#       'question_type': 'text'},
#      {'label': 'Who invited you?',
#       'answer': 'BuzzBridgeCapital',
#       'question_id': 'hs5j82g7',
#       'question_type': 'text'}],
#     'solana_address': None,
#     'user_api_id': 'usr-HCfIssbdOKA4vCm',
#     'user_name': 'tomoya',
#     'user_email': 'tomoya@kreation.jp',
#     'user_first_name': None,
#     'user_last_name': None,
#     'name': 'tomoya',
#     'email': 'tomoya@kreation.jp',
#     'checked_in_at': None,
#     'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-cz8qpYD5BMMhAAG',
#     'event_tickets': [{'amount': 0,
#       'amount_discount': 0,
#       'amount_tax': 0,
#       'api_id': 'eventticket-KYprvXC2G3BJ87G',
#       'checked_in_at': None,
#       'currency': 'usd',
#       'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#       'is_captured': False,
#       'name': 'VIP'}],
#     'event_ticket': {'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-KYprvXC2G3BJ87G',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}}},
#   {'api_id': 'gst-r0sOAiyeZwBuk2Y',
#    'guest': {'api_id': 'gst-r0sOAiyeZwBuk2Y',
#     'approval_status': 'approved',
#     'created_at': '2025-06-09T13:44:52.022Z',
#     'custom_source': None,
#     'eth_address': None,
#     'invited_at': None,
#     'joined_at': None,
#     'phone_number': None,
#     'registered_at': '2025-06-09T13:44:52.021Z',
#     'registration_answers': [{'label': 'Name or Alias',
#       'answer': 'fooomin',
#       'question_id': 'pg6lhrro',
#       'question_type': 'text'},
#      {'label': 'Area of activity in Web3',
#       'answer': 'KOL',
#       'question_id': 'jlm8db1x',
#       'question_type': 'text'},
#      {'label': 'Telegram handle',
#       'answer': 'fooomin',
#       'question_id': 'vd7qlwtn',
#       'question_type': 'text'},
#      {'label': 'X (Twitter) handle',
#       'answer': 'https://x.com/fooomin_crypto',
#       'question_id': 'j7ohhsuw',
#       'question_type': 'text'},
#      {'label': 'Who invited you?',
#       'answer': 'BuzzBrideCapital',
#       'question_id': 'hs5j82g7',
#       'question_type': 'text'}],
#     'solana_address': None,
#     'user_api_id': 'usr-Y1G0cFWSuKmWC5E',
#     'user_name': 'フーミン',
#     'user_email': 'knot.blgs@gmail.com',
#     'user_first_name': 'fooomin',
#     'user_last_name': '',
#     'name': 'フーミン',
#     'email': 'knot.blgs@gmail.com',
#     'checked_in_at': None,
#     'check_in_qr_code': 'https://lu.ma/check-in/evt-tP03iqkZlwNKzBh?pk=g-dQog58wlWBscfJf',
#     'event_tickets': [{'amount': 0,
#       'amount_discount': 0,
#       'amount_tax': 0,
#       'api_id': 'eventticket-7cXl61CTK9wLJUY',
#       'checked_in_at': None,
#       'currency': 'usd',
#       'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#       'is_captured': False,
#       'name': 'VIP'}],
#     'event_ticket': {'amount': 0,
#      'amount_discount': 0,
#      'amount_tax': 0,
#      'api_id': 'eventticket-7cXl61CTK9wLJUY',
#      'checked_in_at': None,
#      'currency': 'usd',
#      'event_ticket_type_api_id': 'evtticktyp-AbItMZrOnB2KW6D',
#      'is_captured': False,
#      'name': 'VIP'}}}],
#  'has_more': True,
#  'next_cursor': 'gst-r0sOAiyeZwBuk2Y'}
